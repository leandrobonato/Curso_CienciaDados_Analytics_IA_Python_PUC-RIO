# %% [markdown]
# #1. Perguntas e objetivos
# Para este projeto foi dividido em novas pequenas perguntas que podem ser respondidas com os dados públicos coletados, e com isso, chegar em uma breve conclusão sobre alguns dos problemas que o nosso planeta enfrenta a como entender e ajudar de alguma forma e melhorar nossa qualidade de vida (geral).
#
# 1. Qual foi a emissão de carbono no planeta por ano?
# 2. Qual foi a emissão de carbono no planeta por década?
# 3. Emissão de carbono no planeta por país.
# 4. Qual foi a emissão de carbono no planeta por país por ano?
# 5. Qual foi a emissão de carbono no planeta por país por década?
# 6. Emissão de carbono no planeta por continente.
# 7. Qual foi a emissão de carbono no planeta por continente por ano?
# 8. Qual foi a emissão de carbono no planeta por continente por década?
# 9. Sobre alguns dados coletados estarem negativos.
# 10. Quais são os países que possuem emissão negativa?
# 11. Quais são os continentes que possuem emissão negativa?

# %% [markdown]
# #2. Coleta dos dados
# As seguintes fontes de dados foram usadas para a coleta dos dados, são elas: Carbon Monitor, Climate Watch (CW), International Energy Agency (IEA), National Aeronautics and Space Administration (NASA), Organização das Nações Unidas (ONU), Our World in Data, World Bank Group, porém nem todas serão usadas, todos os detalhes estarão na sequência.
#
# Todas as organizações listadas anteriormente, possuem dados públicos que foram cuidadosamente baixados, interpretados e verificados para a organização deste projeto. Abaixo os links para dos dados.

# %% [markdown]
# #3. Arquivos de dados e detalhamento

# %% [markdown]
# ##3.1. Carbon Monitor
#
# Link: https://carbonmonitor.org
#
# Arquivo único para a fonte de dados, que já está compilado em um único arquivo: https://datas.carbonmonitor.org/API/downloadFullDataset.php?source=carbon_global
#
# Local no repositório de arquivos coletados: \projeto\Data\Carbon Monitor\
#
# Arquivos de dados: carbonmonitor-global_datas_2025-11-18.csv

# %% [markdown]
# Documentação dos campos:
# - Country / País - refere-se ao país da informação
# - Date / Data - refere-se à data no formato: DD/MM/YYYY que o dado foi coletado
# - Sector / Setor - refere-se ao setor da informação
# - Value / Valor - refere-se ao valor de CO2 emitidos por dia em metros
#
# ####Há um país no final de cada dia que chama-se WORLD que irá servir para se referir à quantidade de emissão de CO2 no mundo inteiro para o respectivo dia

# %% [markdown]
# ##3.2. Climate Watch

# %% [markdown]
# Link: https://www.climatewatchdata.org
#
# Arquivo para download da fonte de dados:
# https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1
#
# Como baixar os arquivos:
# 1. Clique em Download Bulk Data
# 2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
# 3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
# 4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
# - 4.1. Data Sources - All Selected
# - 4.2. Parties and Regions - All Selected
# - 4.3. Sectors - All Selected
# - 4.4. Gases - CO2
# - 4.5. Start Year - 1950
# - 4.6. End Year - 2023
# - 4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.
#
# Local no repositório de arquivos coletados:
# \projeto\Data\Climate Watch\

# %% [markdown]
# Arquivos de dados: CW_Agriculture_area.csv
#
# Documentação dos campos
# 1. Area - Sigla do país
# 2. Short Name - nome curto do tipo dado ou sigla do campo nas referências, com referência de valor de: 1000 ha (hectares)
# - 2.1. share_in_agricultural_area_1 - Arable land - Terra arável
# - 2.2. share_in_agricultural_area_2 - Permanent cropland - Terras agrícolas permanentes
# - 2.3. share_in_agricultural_area_3 - Permanent meadows and pastures  prados e pastagens permanentes
# - 2.4. share_in_land_area_1 - Total Land Area - área total do terreno
# - 2.5. share_in_land_area_2 - Share in Land Area, Agricultura Area - área agrícola do terreno compartilhada
# - 2.6. share_in_land_area_3 - Share in Land Area, Other Land - outras áreas do terreno compartilhada
# - 2.7. share_in_land_area_4 - Share in Land Area, Forest - áreas do terreno compartilhada com florestas
# 3. Years - Anos - estará os valores de anos no restantes das colunas com os dados da quantidade de hectares dividido por 1000 ha

# %% [markdown]
# Arquivos de dados: CW_Agriculture_emissions.csv
#
# Documentação dos campos:
# 1. Area - Sigla do país
# 2. Short Name - nome curto do tipo dado ou sigla do campo nas referências, aqui é para a intensidade de emissões agrícolas e a referências de valores de: kg CO2eq/kg de produto
# - 2.1. emission_intensity_cereals - Cereals excluding rice - Cereais (excluindo arroz)
# - 2.2. emission_intensity_rice - Rice paddy - arrozal
# - 2.3. emission_intensity_meat_cattle - Meat cattle - Carne de Gado
# - 2.4. emission_intensity_meat_goat - Meat goat - Carne de cabra
# - 2.5. emission_intensity_meat_chicken - Meat chicken - Carne de frango
# - 2.6. emission_intensity_meat_pig - Meat pig - Carne de porco
# - 2.7. emission_intensity_meat_buffalo - Meat Buffalo - Carne de búfalo
# - 2.1. emission_intensity_meat_sheep - Meat Sheep - Carne de ovelha
# - 2.2. emission_intensity_milk_cow - Milk Cow - Leite de vaca
# - 2.3. emission_intensity_milk_goat - Milk Goat - Leite de cabra
# - 2.4. emission_intensity_milk_buffalo - Milk Buffalo - Leite de búfalo
# - 2.5. emission_intensity_milk_sheep - Milk Sheep - Leite de ovelha
# - 2.6. emission_intensity_milk_camel - Milk Camel - Leite de camelo
# - 2.7. emission_intensity_eggs - Eggs - Ovos
# 3. Years - Anos - estará os valores de anos no restantes das colunas com os dados da quantidade de kg CO2eq/kg de produto

# %% [markdown]
# Arquivo de dados: CW_Agriculture_employment.csv
#
# Documentação dos campos
# 1. Area - Sigla do país
# 2. Short Name - nome curto do tipo dado para empregados/funcionários/colaboradores nas áreas agrícolas com os valores de referência em percentual
# - 2.1. employment_agri_female - % of female employment - porcentagem de mulheres trabalhando
# - 2.2. employment_agri_male - % of male employment - porcentagem de homens trabalhando
# - 2.3. employment_agri_total - % of total employment - porcentagem total trabalhando
# 3. Years - Anos - estará os valores de anos no restantes das colunas com os dados percentuais

# %% [markdown]
# Arquivos de dados: CW_Agriculture_meat_consumption.csv
#
# Documentação dos campo
# 1. Area - Sigla do país
# 2. Short Name - nome curto do tipo dado para de consumo de carne com os valores de referência em: 1000 t (toneladas) ou quilogramas per capita
# - 2.1. meat_consumption_1 - Beef - carne de gado
# - 2.2. meat_consumption_2 - Pork - carne de porco
# - 2.3. meat_consumption_3 - Poultry - carne de aves
# - 2.3. meat_consumption_4 - Sheep - carne de ovelha
# - 2.1. meat_consumption_per_capita_1 - Beef - carne de gado
# - 2.2. meat_consumption_per_capita_2 - Pork - carne de porco
# - 2.3. meat_consumption_per_capita_3 - Poultry - carne de aves
# - 2.3. meat_consumption_per_capita_4 - Sheep - carne de ovelha
# 3. Years - Anos - estará os valores de anos no restantes das colunas com os dados percentuais

# %% [markdown]
# Arquivos de dados: CW_Agriculture_pesticides_fertilizers.csv
#
# Documentação dos campos
# 1. Area - Sigla do país
# 2. Source - Código do FAOSTAT, que condiz o tipo de fertilizante, herbicida, pesticida e outros agrotóxicos que podem influenciar nos alimentos, conforme a Organização Mundial de Alimentos e Agricultura das Nações Unidas (fonte: https://www.fao.org/home/en)
# 3. Short Name - tipo do agrotóxico do dado, podendo ser pesticidas ou fertilizantes com valores em t (toneladas)
# 4. total_fertilizers - Total Fertilizers - Uso total de fertilizantes na agricultura (N, P2O5, K2O)
# 5. total_pesticides_use - Total pesticides - Uso total de pesticidas
# 6. Years - Anos - estará os valores de anos no restantes das colunas com os dados em toneladas

# %% [markdown]
# Arquivos de dados: CW_Agriculture_value_added.csv
#
# Documentação dos campos
# 1. Area - Sigla do país
# 2. Short Name - nome curto do tipo do dado para o valor adicionado (agricultura) em porcentagem do PIB
# - 2.1. value_added_Agr - valor agregado do PIB em porcentagem
# 3. Years - Anos - estará os valores de anos no restantes das colunas com os dados percentuais

# %% [markdown]
# Arquivos de dados: CW_Agriculture_production_trade.csv
#
# Documentação dos campos:
# 1. Area - Sigla do país
# 2. Short Name - nome curto do tipo dado para do produto agrícola em t (toneladas)
# - 2.1. production_Agr_1 - Agriculture Prouction - Maize - produção agrícola de milho
# - 2.2. production_Agr_2 - Agriculture Prouction - Rice - produção agrícola de arroz
# - 2.3. production_Agr_3 - Agriculture Prouction - Soy - produção agrícola de soja
# - 2.4. production_Agr_4 - Agriculture Prouction - Wheat - produção agrícola de trigo
# - 2.5. production_Agr_5 - Agriculture Prouction - Cattle - produção agrícola de gado
# - 2.6. production_Agr_6 - Agriculture Prouction - Pig - produção agrícola de porco
# - 2.7. production_Agr_7 - Agriculture Prouction - Chicken - produção agrícola de frango
# - 2.8. production_Agr_8 - Agriculture Prouction - Goat - produção agrícola de ovelha
# - 2.9. production_Agr_9 - Agriculture Prouction - Milk Cow - produção agrícola de leite de vaca
# - 2.10. production_Agr_10 - Agriculture Prouction - Milk Goat - produção agrícola de leite de cabra
# - 2.11. trade_export_1 - Trade of agriculture commodities - Export - Rice - Comércio de produtos agrícolas exportação de arroz
# - 2.12. trade_export_2 - Trade of agriculture commodities - Export - Wheat - Comércio de produtos agrícolas exportação de trigo
# - 2.13. trade_export_3 - Trade of agriculture commodities - Export - Soybeans - Comércio de produtos agrícolas exportação de soja
# - 2.14. trade_export_4 - Trade of agriculture commodities - Export - Maize - Comércio de produtos agrícolas exportação de milho
# - 2.15. trade_export_5 - Trade of agriculture commodities - Export - Milk Cow - Comércio de produtos agrícolas exportação de leite de vaca
# - 2.16. trade_export_6 - Trade of agriculture commodities - Export - Chicken - Comércio de produtos agrícolas exportação de frango
# - 2.17. trade_export_7 - Trade of agriculture commodities - Export - Goat - Comércio de produtos agrícolas exportação de cabra
# - 2.18. trade_export_8 - Trade of agriculture commodities - Export - Pig - Comércio de produtos agrícolas exportação de porco
# - 2.19. trade_import_1 - Trade of agriculture commodities - Import - Rice - Comércio de produtos agrícolas exportação de arroz
# - 2.20. trade_import_2 - Trade of agriculture commodities - Import - Wheat - Comércio de produtos agrícolas exportação de trigo
# - 2.21. trade_import_3 - Trade of agriculture commodities - Import - Soybeans - Comércio de produtos agrícolas exportação de soja
# - 2.22. trade_import_4 - Trade of agriculture commodities - Import - Maize - Comércio de produtos agrícolas exportação de milho
# - 2.23. trade_import_5 - Trade of agriculture commodities - Import - Milk Cow - Comércio de produtos agrícolas exportação de leite de vaca
# - 2.24. trade_import_6 - Trade of agriculture commodities - Import - Chicken - Comércio de produtos agrícolas exportação de frango
# - 2.25. trade_import_7 - Trade of agriculture commodities - Import - Goat - Comércio de produtos agrícolas exportação de cabra
# - 2.26. trade_import_8 - Trade of agriculture commodities - Import - Pig - Comércio de produtos agrícolas exportação de porco
# 3. Years - Anos - estará os valores de anos no restantes das colunas com os dados em toneladas

# %% [markdown]
# Arquivos de dados: CW_Agriculture_water.csv
#
# Documentação dos campos
# 1. Area - Sigla do país
# 2. Short Name - nome curto do tipo do dado para o percentual de retirada de água total para áreas agrícolas
# - 2.1. water_withdrawal - Agricultural water withdrawal as % of total water withdrawal - Retirada de água para agricultura como % da retirada total de água
# 3. Years - Anos - estará os valores de anos no restantes das colunas com os dados em percentuais

# %% [markdown]
# Arquivos de dados: CW_HistoricalEmissions_UNFCCC.csv
#
# Documentação dos campos
# 1. country - Sigla do país
# 2. source - tecnologia que realizou a coleta de dados, nesse arquivo terá duas, sendo elas: UNFCCC_AI (por inteligência artificial) e UNFCCC_NAI (Refere-se aos países que não estão listados no Anexo I da Convenção-Quadro das Nações Unidas)
# 3. sector - Setor da emissão do gás que o dado está sendo verificado
# 4. Gas - tipo do gás que está sendo verificado no dado
# 5. Years - Anos - estará os valores de anos no restantes das colunas com os dados dos valores em MtCO₂e (milhões de toneladas de dióxido de carbono equivalente).
#
# Observações para este arquivo
# 1. Há dados com os valores de country (países) com a seguinte informação: ANNEXI, talvez seja o valor do arquivo para o planeta, pois não há essa Contry no arquivo, ao contrário dos demais arquivos, entretanto também não há evidências suficiente para afirmar isso, então, esses campos serão descartados.
# 2. Os valores do source também serão descartados, afinal não é interessante para essa pesquisa.
# 3. Há alguns setores que possuem valores agregados para vários tipos de gases, e outros de tipos de pesquisas que estão juntos, como o objetivo deste projeto é apenas de dióxido de carbono, estes valores serão descartados.

# %% [markdown]
# Arquivos de dados: CW_HistoricalEmissions_PRIMAP.csv
#
# Documentação dos campos
# 1. country - Sigla do país
# 2. sector - Setor da emissão do gás que o dado está sendo verificado
# 2. Gas - tipo do gás que está sendo verificado no dado
# 3. Years - Anos - estará os valores de anos no restantes das colunas com os dados dos valores em MtCO₂e (milhões de toneladas de dióxido de carbono equivalente).
#
# Observações para este arquivo
# 1. Há alguns setores que possuem valores agregados e que são especificamente do gás que está seno pesquisado neste projeto, então será mantido.
# 2. A sigla LULUCF significa Land Use, Land-Use Change, and Forestry - Uso da Terra, Mudança no Uso da Terra e Florestas. Por este motivo será mantido.
# 3. Gases que não são CO2 serão descartados.

# %% [markdown]
# Arquivos de dados: CW_HistoricalEmissions_GCP.csv
#
# Documentação dos campos
# 1. country name - nome do país
# 2. country - Sigla do país
# 3. sector - Setor da emissão do gás que o dado está sendo verificado
# 4. source - sigla da instituição que realizou a coleta dos dados
# 5. Gas - tipo do gás que está sendo verificado no dado
# 6. Years - Anos - estará os valores de anos no restantes das colunas com os dados dos valores em MtCO₂e (milhões de toneladas de dióxido de carbono equivalente).

# %% [markdown]
# Arquivos de dados: CW_historical_emissions.csv
#
# Documentação dos campos
# 1. ISO - Sigla do país
# 2. country - nome do país
# 3. data source - sigla da instituição que realizou a coleta dos dados
# 4. sector - Setor da emissão do gás que o dado está sendo verificado
# 5. Gas - tipo do gás que está sendo verificado no dado
# 6. Unit - unidade de medida do gás
# 7. Years - Anos - estará os valores de anos no restantes das colunas com os dados dos valores em MtCO₂e (milhões de toneladas de dióxido de carbono equivalente).
#
# Observações para este arquivo
# 1. Há alguns setores que possuem valores agregados e que são especificamente do gás que está seno pesquisado neste projeto, então será mantido.
# 2. A sigla LULUCF significa Land Use, Land-Use Change, and Forestry - Uso da Terra, Mudança no Uso da Terra e Florestas. Por este motivo será mantido.
# 3. Gases que não são CO2 serão descartados.
# 4. Há dados com os valores de ISO e country (países) com a seguinte informação: ANNEXI, talvez seja o valor do arquivo para o planeta, pois não há essa Contry no arquivo, ao contrário dos demais arquivos, entretanto também não há evidências suficiente para afirmar isso, então, esses campos serão descartados.
# 5. Os valores do source também serão descartados, afinal não é interessante para essa pesquisa.

# %% [markdown]
# Arquivos de dados: CW_HistoricalEmissions_ClimateWatch.csv
#
# Documentação dos campos
# 1. country - sigla do país
# 2. source - sigla da instituição que realizou a coleta dos dados
# 3. sector - Setor da emissão do gás que o dado está sendo verificado
# 4. Gas - tipo do gás que está sendo verificado no dado
# 5. Years - Anos - estará os valores de anos no restantes das colunas com os dados dos valores em MtCO₂e (milhões de toneladas de dióxido de carbono equivalente).
#
# Observações para este arquivo
# 1. Há alguns setores que possuem valores agregados e que são especificamente do gás que está seno pesquisado neste projeto, então será mantido.
# 2. A sigla LULUCF significa Land Use, Land-Use Change, and Forestry - Uso da Terra, Mudança no Uso da Terra e Florestas. Por este motivo será mantido.
# 3. Gases que não são CO2 serão descartados.
# 4. Os valores do source também serão descartados, afinal não é interessante para essa pesquisa.

# %% [markdown]
# ##3.3. International Energy Agency (IEA)
#
# Link: https://www.iea.org
#
# Link para download direto, onde será um arquivo XLSX e terá que fazer um cadastro gratuito no site para conseguir realizar o download da fonte de dados: https://www.iea.org/data-and-statistics/data-product/global-energy-review-co2-emissions-in-2021#
#
# A observação da fonte de dados baixada é de as informações serem de 2019 à 2021 e apenas informações de alguns países, mundo, a quantidade de emissão do ano em metros de CO2, e a taxa de crescimento comparada com o ano anterior.
#
# Local no repositório de arquivos coletados: \projeto\Data\iea\

# %% [markdown]
# Arquivos de dados: CO2 Emissions in 2021 - gas emissions.csv
#
# Documentação dos campos
# 1. Type emission - tipo de emissão
# 2. CO2 emissions - origem de emissão de CO2
# 3. Unit - unidade de medida da emissão de CO2
# 4. Year - ano da emissão de CO2 conforme a unidade de medida
# 5. Grow rate % Year - taxa de variação em porcentagem entre os anos 1 e 2, 2 e 3

# %% [markdown]
# Arquivos de dados: CO2 Emissions in 2021 - countries.csv
#
# Documentação dos campos
# 1. Type emission - tipo de emissão
# 2. country - país de emissão de CO2
# 3. Unit - unidade de medida da emissão de CO2
# 4. Year - ano da emissão de CO2 conforme a unidade de medida
# 5. Grow rate % Year - taxa de variação em porcentagem entre os anos 1 e 2, 2 e 3

# %% [markdown]
# ##3.4. National Aeronautics and Space Administration (NASA)
#
# Link para o site: https://data.nasa.gov/dataset/
#
# Link para download direto: https://acdisc.gsfc.nasa.gov/data/CMS/CMSFluxTotal.3
#
# Os passos para download são:
# 1. Clique em Once Registered, you can click here.
# 2. Caso não tenha um cadastro, crie um.
# 3. Depois realize o login
# 4. Volte na página do link direto para download
# 5. Clique no arquivo CMSFluxTotal201001_202212_v3.nc
# 6. Baixe o arquivo.
#
# Observações sobre os arquivos
# 1. Os arquivos da NASA possuem mais de 500 mb, e o GitHub não aceita tais arquivos, então pra isso foi feito um algoritmo para separá-los em arquivos menores com no máximo 50 mb cada um.
#
# Local no repositório dos arquivos: \projeto\Data\NASA\

# %% [markdown]
# Arquivos de dados:
# 1. CMSFluxTotal201001_202212_v3_part_1.csv
# 2. CMSFluxTotal201001_202212_v3_part_2.csv
# 3. CMSFluxTotal201001_202212_v3_part_3.csv
# 4. CMSFluxTotal201001_202212_v3_part_4.csv
# 5. CMSFluxTotal201001_202212_v3_part_5.csv
# 6. CMSFluxTotal201001_202212_v3_part_6.csv
# 7. CMSFluxTotal201001_202212_v3_part_7.csv
# 8. CMSFluxTotal201001_202212_v3_part_8.csv
# 9. CMSFluxTotal201001_202212_v3_part_9.csv
# 10. CMSFluxTotal201001_202212_v3_part_10.csv
# 11. CMSFluxTotal201001_202212_v3_part_11.csv
#
# Observação dos arquivos:
# 1. Os arquivos estão separados em tamanhos de 50mb por causa da importação para o github.
#
# Documentação dos campos
# 1. time - Data e hora da coleta dos dados, no formato: YYYY-MM-DD HH:MM:SS
# 2. latitude - é os graus de latitude do registro
# 3. longitude - é os graus de longitude do registro
# 4. total_post - quantidade de CO2 emitido na área em g/m^2/day (gramas por metro quadrado por dia)
# 5. area - é a área em m2 (metros quadrados)

# %% [markdown]
# ##3.5. Organização das Nações Unidas (ONU)
#
# Link: https://unfccc.int/
#
# Link para os DataSets: https://di.unfccc.int/time_series
#
# São vários datasets e conforme vai navegando poderá ir baixando os dados, exemplo, se clicar em Flexible Queries > Preencher todas as informações relacionadas à carbbono (em inglês Carbon) ou CO² mostrará então um relatório em tabela para exportar para CSV, ou em Time Series - Annex I, poderá ir filtrando as informações relacionadas com estas palavras-chaves e então modificando o resultado da consulta da tabela, e com isso exportar para XLSX e posteriormente converter para CSV.
#
# Local dos arquivos no repositório: \projeto\Data\ONU\

# %% [markdown]
# Time Series - CO₂ total with LULUCF, in kt.csv
#
# Filtros realizados para emitir o relatório:
# 1. URL: https://di.unfccc.int/time_series
# 2. CO₂ total with LULUCF (Uso da Terra, Mudança no Uso da Terra e Florestas).
#
# Documentação dos campos
# 1. Party - País ou parte do mundo do registro
# 2. Base year - ano base
# 3. Campos de anos
# 4. Last inventory Year (2021) - ano de 2021 que foi a última coleta
# 5. Change from base yar to latest reported year - comparativo entre a última coleta e a coleta base

# %% [markdown]
# Annual greenhouse gas (GHG) emissions for Annex I, in kt.csv
#
# Filtros realizados para emitir o relatório:
# 1. URL: https://di.unfccc.int/detailed_data_by_party
# 2. Select Party - Annex I
# 3. Select Base Year - All Years
# 4. Select Totals - Total GHG emissions with LULUCF
# 5. Select Aggregate GHGs - CO2
# 6. Select kt - kt
#
# Documentação dos campos
# 1. Category - Categoria do setor de emissão
# 2. Base year - ano base
# 3. Campos de anos
# 4. Last inventory Year (2021) - ano de 2021 que foi a última coleta

# %% [markdown]
# Annual Net emissions_removals in kt.csv
#
# Filtros realizados para emitir o relatório:
# 1. URL: https://di.unfccc.int/flex_annex1
# 2. Select Party - Annex I
# 3. Select Base Year - All Years
# 4. Select Totals - Total GHG emissions with LULUCF
# 5. Select Total for category
# 6. Select Type of valye: Net emiissions/removals
# 7. Select kt - kt
#
# Documentação dos campos:
# 1. Category - Categoria do setor de emissão
# 2. Base year - ano base
# 3. Campos de anos
# 4. Last inventory Year (2021) - ano de 2021 que foi a última coleta

# %% [markdown]
# ##3.6. Food And Agriculture Organization of the United Nations - Organização de comida e agricultura das nações unidas
#
# Link: https://www.fao.org/faostat/en/?spm=a2ty_o01.29997173.0.0.145bc921b3fju9#data/GT
#
# Local do repositórios dos dados: \projeto\Data\FAOSTAT\
#
# Filtros utilizados para obter os dados
# 1. Countries - Select all
# 2. Elements - Emissions CO2
# 3. Items - Select All
# 4. Years - Select all
# 5. FAO Source - Select All
# 6. Ohters Sources - Select All
#
# Para realização do download:
# 1. Seguir para Bulk Downloads
# 2. All Data
# 3. Descompactar os arquivos
# 4. O arquivo com os dados é o Emissions_Totals_E_All_Data.csv
#
# Observação principal:
# - Será usado o arquivo Emissions_Totals_E_All_Data_NOFLAG.csv, pois o arquivo com FLAGs, há marcações que não estão descritas na documentação, então não sabe-se o que poderá ser estas marcações.
#
# - Os demais arquivos são de códigos e outros, entretanto poderá ser descartado para este projeto.

# %% [markdown]
# Documentação dos campos:
# 1. Area code - código da área - descrito no arquivo de Emissions_Totals_E_AreaCodes.csv
# 2. Area code M49 - código da área conforme a tabela M49 - descrito no arquivo de Emissions_Totals_E_AreaCodes.csv
# 3. Area - Nome do país ou da área do registro
# 4. Item Code - código dos itens
# * Era para ter os registros de códigos dos itens no arquivo: Emissions_Totals_E_ItemCodes.csv, porém este arquivo não possuí nenhum informação, apenas o cabeçalho.
# 5. Item - Nome do item
# 6. Element Code - Código do elemento do registro e/ou da emissão - disponível no arquivo Emissions_Totals_E_Elements.csv
# 7. Element - nome do elemento do registro
# 8. Source Code - código da fonte de dados - detalhes no arquivo: Emissions_Totals_E_Sources.csv
# 9. Source - fonte dos dados
# 10. unit - unidade de medida do elemento
# 11. Years - campos com os Anos
#
# Observação dos campos
# * arquivo com flags: Y - representando o ano, o número do ano no formato YYYY - X - Letra da Flag, ficando da seguinte forma: Y2025X
#
# * no arquivo que possuí as flags, há anos que possuem a flag: N, entretanto não há informações sobre esta flag no arquivo e flags, então por este motivo foi optado por usar o arquivo NOFLAG
#
# * o arquivo NOFLAG possuí apenas o Y seguido do ano em 4 dígitos (Ex.: Y2025)

# %% [markdown]
# ##3.7. Our World in Data: https://ourworldindata.org
#
# Link para os dados: https://ourworldindata.org/search?q=co2
#
# Pesquisar por CO2 irá ser mostrada as seguintes informações, realizar download das informações abaixo:
# 1. CO₂ emissions per capita
# 2. Annual CO₂ emissions
# 3. Annual concentration of atmospheric carbon dioxide
# 4. Annual CO₂ emissions by world region
# 5. Share of global CO₂ emissions
# 6. Cumulative CO₂ emissions
# 7. Cumulative CO₂ emissions by world region
# 8. Share of global cumulative CO₂ emissions
# 9. Carbon dioxide emissions factors
#
# Local no repositório dos arquivos: \projeto\Data\ourworldindata\

# %% [markdown]
# Annual-co2-emissions-per-country.csv
#
# Documentação dos campos:
# 1. Entity - País
# 2. Code - Sigla do País
# 3. Year - Ano
# 4. Annual CO2 Emissions - valor anual de emissão de CO2
#
# Observação dos campos:
# 1. Há um país chamado WORLD ou mundo para agregar tudo
# 2. Os valores de referência estão em toneladas.

# %% [markdown]
# annual-co-emissions-by-region.csv
#
# Documentação dos campos:
# 1. Entity - País
# 2. Code - Sigla do País
# 3. Year - Ano
# 4. Annual CO2 Emissions - valor anual de emissão de CO2
#
# Observação dos campos:
# 1. Há um país chamado WORLD ou mundo para agregar tudo
# 2. Os valores de referência estão em toneladas.
# 3. Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.

# %% [markdown]
# annual-share-of-co2-emissions.csv
#
# Documentação dos campos:
# 1. Entity - País
# 2. Code - Sigla do País
# 3. Year - Ano
# 4. Annual CO2 Emissions - valor anual de emissão de CO2
#
# Observação dos campos:
# 1. Há um país chamado WORLD ou mundo para agregar tudo
# 2. Os valores de referência estão em toneladas.
# 3. Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.

# %% [markdown]
# carbon-dioxide-emissions-factor.csv
#
# Documentação dos campos:
# 1. Entity - Fatores que emitem gás CO2
# 2. Code - não há informações neste campo
# 3. Year - Ano
# 4. CO₂ emission factor - valor da emissão de CO2 do fator
#
# Observação dos campos:
# 1. Os valores de referência estão em toneladas.
# 2. Todos os anos do arquivo referem-se à 2023

# %% [markdown]
# co2-long-term-concentration.csv
#
# Documentação dos campos:
# 1. Entity - é apenas 1 valor que é referência para o mundo todo
# 2. Code - Sigla do mundo, apenas 1 sigla
# 3. Year - Ano - valores negativos
# 4. Annual concentration of atmospheric carbon dioxide - quantidade de concentração anual de dióxido de carbono na atmosfera
#
# Observação dos campos:
# 1. Há apenas o país chamado WORLD ou mundo para agregar tudo
# 2. Os valores de referência estão em toneladas.
# 3. Há mais da metade dos registros que estão com o valor de ano em negativo, e um valor bem estranho, exemplo: -803719

# %% [markdown]
# co-emissions-per-capita.csv
#
# Documentação dos campos
# 1. Entity - nome do país
# 2. Code - sigla do país
# 3. Year - Ano
# 4. Annual CO₂ emissions (per capita) - quantidade de CO2 emitido per capita
#
# Observação dos campos:
# 1. Há um campo chamado WORLD ou mundo para agregar tudo
# 2. Os valores de referência estão em toneladas.
# 3. Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.

# %% [markdown]
# cumulative-co2-emissions.csv
#
# Documentação dos campos:
# 1. Entity - nome do país
# 2. Code - sigla do país
# 3. Year - Ano
# 4. Cumulative CO₂ emissions - quantidade acumulada ao longo dos anos de emissão de CO2
#
# Observação dos campos:
# 1. Há um campo chamado WORLD ou mundo para agregar tudo
# 2. Os valores de referência estão em toneladas.
# 3. Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.

# %% [markdown]
# share-of-cumulative-co2.csv
#
# Documentação dos campos:
# 1. Entity - nome do país
# 2. Code - sigla do país
# 3. Year - Ano
# 4. Share of global cumulative CO₂ emissions - emissão de CO2 acumulada de áreas compartilhadas
#
# Observação dos campos:
# 1. Há um campo chamado WORLD ou mundo para agregar tudo
# 2. Os valores de referência estão em toneladas.
# 3. Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.

# %% [markdown]
# owid-co2-data.csv
#
# Link para download https://github.com/owid/co2-data
#
# Arquivo de documentação: owid-co2-codebook.csv
#
# Documentação dos campos:
# 1. Country - Nome do País
# 2. Year - Ano
# 3. ISO_CODE - Sigla do País
# 4. Population - População
# 5. gdp - Gross domestic product (GDP) - Produção econômica total de um país ou região por ano
# 6. cement_co2 - Annual CO₂ emissions from cement - Emissões anuais de dióxido de carbono (CO₂) provenientes do cimento
# 7. cement_co2_per_capita - Annual CO₂ emissions from cement (per capita) - Emissões anuais de dióxido de carbono (CO₂) provenientes do cimento per capita
# 8. co2 - Annual CO₂ - Emissão de CO2 anual
# 9. co2_growth_abs - Annual CO₂ emissions growth (abs) - Crescimento anual das emissões de CO₂ (absoluto)
# 10. co2_growth_prct - Annual CO₂ emissions growth (%) - Crescimento anual das emissões de CO₂ (%)
# 11. co2_including_luc - Annual CO₂ emissions including land-use change - Emissões anuais de CO₂, incluindo mudanças no uso da terra.
# 12. co2_including_luc_growth_abs - Growth rate of emissions including land-use change - Taxa de crescimento das emissões, incluindo mudanças no uso da terra
# 13. co2_including_luc_growth_prct - Growth rate of emissions including land-use change (%) - Taxa de crescimento das emissões, incluindo mudanças no uso da terra (%)
# 14. co2_including_luc_per_capita - Annual CO₂ emissions including land-use change per capita - Emissões anuais de CO₂, incluindo mudanças no uso da terra (por pessoa)
# 15. co2_including_luc_per_gdp - Annual CO₂ emissions including land-use change per GDP - Emissões anuais de CO₂, incluindo mudanças no uso da terra (por PIB)
# 16. co2_including_luc_per_unit_energy - Annual CO₂ emissions including land-use change per unit energy - Emissões anuais de CO₂, incluindo mudanças no uso da terra (por unidade de energia)
# 17. co2_per_capita - CO₂ emissions per capita - Emissões de CO₂ por pessoa
# 18. co2_per_gdp - Annual CO₂ emissions per GDP (kg per international-$) - Emissões anuais de CO₂ por PIB (kg por dólar internacional)
# 19. co2_per_unit_energy - Annual CO₂ emissions per unit energy (kg per kilowatt-hour) - Emissões anuais de CO₂ por unidade de energia (kg por quilowatt-hora)
# 20. coal_co2 - Annual CO₂ emissions from coal - Emissões anuais de CO₂ do carvão
# 21. coal_co2_per_capita - Annual CO₂ emissions from coal (per capita) - Emissões anuais de CO₂ do carvão (por pessoa)
# 22. consumption_co2 - Annual consumption-based CO₂ emissions - Emissões anuais de CO₂ baseadas no consumo
# 22. consumption_co2_per_capita - Per capita consumption-based CO₂ emissions - Emissões de CO₂ baseadas no consumo (por pessoa)
# 23. consumption_co2_per_gdp - Annual consumption-based CO₂ emissions per GDP (kg per international-$) - Emissões anuais de CO₂ baseadas no consumo (por PIB)
# 24. cumulative_cement_co2 - Cumulative CO₂ emissions from cement - Emissões acumuladas de CO₂ do cimento
# 25. cumulative_co2 - Cumulative CO₂ emissions - Emissões acumuladas de CO₂
# 26. cumulative_co2_including_luc - Cumulative CO₂ emissions including land-use change - Emissões acumuladas de CO₂, incluindo mudanças no uso da terra
# 27. cumulative_coal_co2 - Cumulative CO₂ emissions from coal - Emissões acumuladas de CO₂ do carvão
# 28. cumulative_flaring_co2 - Cumulative CO₂ emissions from flaring - Emissões acumuladas de CO₂ da queima de gás
# 29. cumulative_gas_co2 - Cumulative CO₂ emissions from gas - Emissões acumuladas de CO₂ do gás
# 30. cumulative_luc_co2 - Cumulative CO₂ emissions from land-use change - Emissões acumuladas de CO₂ da mudança no uso da terra
# 31. cumulative_oil_co2 - Cumulative CO₂ emissions from oil - Emissões acumuladas de CO₂ do petróleo
# 32. cumulative_other_co2 - Cumulative CO₂ emissions from other industry - Emissões acumuladas de CO₂ de outras indústrias
# 33. energy_per_capita - Primary energy consumption per capita - Consumo de energia primária por pessoa
# 34. energy_per_gdp - Primary energy consumption per GDP - Consumo de energia primária por PIB
# 35. flaring_co2 - Annual CO₂ emissions from flaring - Emissões anuais de CO₂ da queima de gás
# 36. flaring_co2_per_capita - Annual CO₂ emissions from flaring (per capita) - Emissões anuais de CO₂ da queima de gás (por pessoa)
# 37. gas_co2 - Annual CO₂ emissions from gas - Emissões anuais de CO₂ do gás
# 38. gas_co2_per_capita - Annual CO₂ emissions from gas (per capita) - Emissões anuais de CO₂ do gás (por pessoa)
# 39. ghg_excluding_lucf_per_capita - Per capita greenhouse gas emissions from fossil fuels and industry - Emissões per capita de gases de efeito estufa de combustíveis fósseis e indústria
# 40. ghg_per_capita - Per capita greenhouse gas emissions including land use - Emissões per capita de gases de efeito estufa, incluindo uso da terra
# 41. land_use_change_co2 - Annual CO₂ emissions from land-use change - Emissões anuais de CO₂ da mudança no uso da terra
# 42. land_use_change_co2_per_capita - Annual CO₂ emissions from land-use change per capita - Emissões anuais de CO₂ da mudança no uso da terra (por pessoa)
# 43. methane - Annual methane emissions including land use - Emissões anuais de metano, incluindo uso da terra
# 44. methane_per_capita - Per capita methane emissions including land use - Emissões per capita de metano, incluindo uso da terra
# 45. nitrous_oxide - Annual nitrous oxide emissions including land use - Emissões anuais de óxido nitroso, incluindo uso da terra
# 46. nitrous_oxide_per_capita - Per capita nitrous oxide emissions including land use - Emissões per capita de óxido nitroso, incluindo uso da terra
# 47. oil_co2 - Annual CO₂ emissions from oil - Emissões anuais de CO₂ do petróleo
# 48. oil_co2_per_capita - Annual CO₂ emissions from oil (per capita) - Emissões anuais de CO₂ do petróleo (por pessoa)
# 49. other_co2_per_capita - Annual CO₂ emissions from other industry (per capita) - Emissões anuais de CO₂ de outras indústrias (por pessoa)
# 50. other_industry_co2 - Annual CO₂ emissions from other industry - Emissões anuais de CO₂ de outras indústrias
# 51. primary_energy_consumption - Primary energy consumption - Consumo de energia primária
# 52. share_global_cement_co2 - Share of global annual CO₂ emissions from cement - Participação nas emissões globais anuais de CO₂ do cimento
# 53. share_global_co2 - Share of global annual CO₂ emissions - Participação nas emissões globais anuais de CO₂
# 54. share_global_co2_including_luc - Share of global annual CO₂ emissions including land-use change - Participação nas emissões globais anuais de CO₂, incluindo mudanças no uso da terra
# 55. share_global_coal_co2 - Share of global annual CO₂ emissions from coal - Participação nas emissões globais anuais de CO₂ do carvão
# 56. share_global_cumulative_cement_co2 - Share of global cumulative CO₂ emissions from cement - Participação nas emissões globais acumuladas de CO₂ do cimento
# 57. share_global_cumulative_co2 - Share of global cumulative CO₂ emissions - Participação nas emissões globais acumuladas de CO₂
# 58. share_global_cumulative_co2_including_luc - Share of global cumulative CO₂ emissions including land-use change - Participação nas emissões globais acumuladas de CO₂, incluindo mudanças no uso da terra
# 59. share_global_cumulative_coal_co2 - Share of global cumulative CO₂ emissions from coal - Participação nas emissões globais acumuladas de CO₂ do carvão
# 60. share_global_cumulative_flaring_co2 - Share of global cumulative CO₂ emissions from flaring - Participação nas emissões globais acumuladas de CO₂ da queima de gás
# 61. share_global_cumulative_gas_co2 - Share of global cumulative CO₂ emissions from gas - Participação nas emissões globais acumuladas de CO₂ do gás
# 62. share_global_cumulative_luc_co2 - Share of global cumulative CO₂ emissions from land-use change - Participação nas emissões globais acumuladas de CO₂ da mudança no uso da terra
# 63. share_global_cumulative_oil_co2 - Share of global cumulative CO₂ emissions from oil - Participação nas emissões globais acumuladas de CO₂ do petróleo
# 64. share_global_cumulative_other_co2 - Share of global cumulative CO₂ emissions from other industry - Participação nas emissões globais acumuladas de CO₂ de outras indústrias
# 65. share_global_flaring_co2 - Share of global annual CO₂ emissions from flaring - Participação nas emissões globais anuais de CO₂ da queima de gás
# 66. share_global_gas_co2 - Share of global annual CO₂ emissions from gas - Participação nas emissões globais anuais de CO₂ do gás
# 67. share_global_luc_co2 - Share of global annual CO₂ emissions from land-use change - Participação nas emissões globais anuais de CO₂ da mudança no uso da terra
# 68. share_global_oil_co2 - Share of global annual CO₂ emissions from oil - Participação nas emissões globais anuais de CO₂ do petróleo
# 69. share_global_other_co2 - Share of global annual CO₂ emissions from other industry - Participação nas emissões globais anuais de CO₂ de outras indústrias
# 70. share_of_temperature_change_from_ghg - Share of contribution to global warming - Participação na contribuição para o aquecimento global
# 71. temperature_change_from_ch4 - Change in global mean surface temperature caused by methane emissions - Mudança na temperatura média global causada pelas emissões de metano
# 72. temperature_change_from_co2 - Change in global mean surface temperature caused by CO₂ emissions - Mudança na temperatura média global causada pelas emissões de CO₂
# 73. temperature_change_from_ghg - Change in global mean surface temperature caused by greenhouse gas emissions - Mudança na temperatura média global causada pelas emissões de gases de efeito estufa
# 74. temperature_change_from_n2o - Change in global mean surface temperature caused by nitrous oxide emissions - Mudança na temperatura média global causada pelas emissões de óxido nitroso
# 75. total_ghg - Annual greenhouse gas emissions including land use - Emissões anuais de gases de efeito estufa, incluindo uso da terra
# 76. total_ghg_excluding_lucf - Annual greenhouse gas emissions from fossil fuels and industry - Emissões anuais de gases de efeito estufa de combustíveis fósseis e indústria
# 77. trade_co2 - Annual CO₂ emissions embedded in trade - Emissões anuais de CO₂ incorporadas no comércio
# 78. trade_co2_share - Share of annual CO₂ emissions embedded in trade - Participação nas emissões anuais de CO₂ incorporadas no comércio
#
# Observações dos campos:
# 1. Há um campo chamado WORLD ou mundo para agregar tudo
# 2. Os valores de referência estão em toneladas.
# 3. Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.

# %% [markdown]
# #4. Scripts auxiliares

# %% [markdown]
# ##4.1 Conversão de arquivos NC e Junção.
# Este é um script para ler e converter os arquivos de dados que possuem o formato "NC", e após finalizar a conversão desses arquivos o script irá combinar os arquivos para o formato CSV que estiverem com o mesmo nome.

# %%
pip install xarray

# %%
# %restart_python

# %%
pip install pandas

# %%
# %restart_python

# %%
import xarray as xr
import pandas as pd
import os

# Caminho para a pasta contendo os arquivos .nc
data_path = "D:/dados_nc"  # Altere para o caminho correto da sua pasta

# Listar os arquivos .nc na pasta
file_paths = [os.path.join(data_path, file) for file in os.listdir(data_path) if file.endswith(".nc")]

# Verificar se há arquivos .nc
if not file_paths:
    raise ValueError("Nenhum arquivo .nc encontrado na pasta.")

# Carregar cada arquivo individualmente e garantir que os índices de tempo sejam monotônicos
datasets = []
for file_path in file_paths:
    try:
        ds = xr.open_dataset(file_path, decode_times=False)
        
        # Garantir que a dimensão 'time' esteja monotônica
        if "time" in ds.variables:
            ds = ds.sortby("time")  # Ordenar por 'time'
        
        datasets.append(ds)
    except Exception as e:
        print(f"Falha ao carregar o arquivo {file_path}: {e}")

# Concatenar os datasets manualmente
try:
    combined_data = xr.concat(datasets, dim="time")  # Usar 'time' como dimensão de concatenação
    print("Arquivos combinados com sucesso!")
except Exception as e:
    raise ValueError(f"Falha ao combinar arquivos: {e}")

# Decodificar manualmente a variável 'time' usando cftime
if "time" in combined_data.variables:
    time_units = combined_data["time"].attrs.get("units", "")
    raw_time_values = combined_data["time"].values  # Valores brutos (números)

    # Identificar o tipo de unidade de tempo
    if "days since" in time_units:
        reference_date = pd.Timestamp(time_units.split("days since ")[1])  # Extrair a data de referência
        decoded_dates = [reference_date + pd.Timedelta(days=int(t)) for t in raw_time_values]
    elif "months since" in time_units:
        reference_date = pd.Timestamp(time_units.split("months since ")[1])  # Extrair a data de referência
        decoded_dates = [reference_date + pd.DateOffset(months=int(t)) for t in raw_time_values]
    else:
        raise ValueError(f"Unidades de tempo não suportadas: {time_units}")

    # Atualizar a variável 'time' no dataset
    combined_data["time"] = xr.Variable(
        dims=combined_data["time"].dims,
        data=decoded_dates,
        attrs=combined_data["time"].attrs
    )

# Converter para DataFrame
df = combined_data.to_dataframe()

# Salvar como CSV
output_path = os.path.join(data_path, "dados_combinados.csv")
df.to_csv(output_path)

print(f"Arquivos combinados e salvos como CSV em: {output_path}")

# %% [markdown]
# ##4.2 Separação de arquivos CSV
# Há alguns arquivos que após a conversão do formato NC para CSV, que ficaram com um tamanho muito grande, e então não puderam ser importados no GitHub, então foi criado esse script para separá-los em arquivos de 50 mb no máximo e enviar para o GitHub.

# %%
import pandas as pd
import os

def split_csv_by_size(input_file, output_dir, max_size_mb=50):
    """
    Separa um arquivo CSV grande em arquivos menores com base no tamanho máximo.

    :param input_file: Caminho para o arquivo CSV de entrada.
    :param output_dir: Diretório onde os arquivos divididos serão salvos.
    :param max_size_mb: Tamanho máximo de cada arquivo dividido (em MB).
    """
    # Converte o tamanho máximo para bytes
    max_size_bytes = max_size_mb * 1024 * 1024

    # Cria o diretório de saída, se ele não existir
    os.makedirs(output_dir, exist_ok=True)

    # Lê o cabeçalho do arquivo CSV
    with open(input_file, 'r') as f:
        header = f.readline()

    # Inicializa variáveis
    chunk_size = 10000  # Número inicial de linhas por chunk (ajustável)
    file_index = 1
    current_chunk = []
    current_size = len(header.encode('utf-8'))  # Começa com o tamanho do cabeçalho

    # Lê o arquivo CSV em chunks
    for chunk in pd.read_csv(input_file, chunksize=chunk_size):
        for _, row in chunk.iterrows():
            # Converte a linha para string e calcula seu tamanho em bytes
            row_str = ','.join(map(str, row.values)) + '\n'
            row_size = len(row_str.encode('utf-8'))

            # Verifica se a linha cabe no arquivo atual
            if current_size + row_size > max_size_bytes:
                # Salva o chunk atual como um novo arquivo
                output_file = os.path.join(output_dir, f'part_{file_index}.csv')
                with open(output_file, 'w') as f:
                    f.write(header)
                    f.writelines(current_chunk)
                
                # Reinicia variáveis para o próximo arquivo
                file_index += 1
                current_chunk = [row_str]
                current_size = len(header.encode('utf-8')) + row_size
            else:
                # Adiciona a linha ao chunk atual
                current_chunk.append(row_str)
                current_size += row_size

    # Salva o último chunk, se houver
    if current_chunk:
        output_file = os.path.join(output_dir, f'part_{file_index}.csv')
        with open(output_file, 'w') as f:
            f.write(header)
            f.writelines(current_chunk)

    print(f"Arquivo dividido em {file_index} partes.")

# Exemplo de uso
input_csv = "D:/dados_nc/.csv"
output_directory = "caminho/para/diretorio_saida"
split_csv_by_size(input_csv, output_directory, max_size_mb=50)

# %% [markdown]
# #5. Volumes de dados
# Todos os arquivos de dados coletados foram importados no Dataricks em volumes de dados, e com isso foram criadas as tabelas, abaixo a lista de tabelas.

# %% [markdown]
# - carbon_monitor
# - cw_agriculture_area
# - cw_agriculture_emissions
# - cw_agriculture_employment
# - cw_agriculture_meat_consumiption
# - cw_agriculture_pestiicides_fertilizers
# - cw_agriculture_value_added
# - cw_agriculture_water
# - cw_historical_emissions
# - cw_historical_emissions_climate_watch
# - cw_historical_emissions_gcp
# - cw_historical_emissions_primap
# - cw_historical_emissions_unfcc
# - faostat_emissions_totals
# - iea_emissions
# - iea_gas_emissions
# - nasa_cms_flux_total
# - onu_annual_emissions_removals
# - onu_annual_greenhouse_gas
# - onu_time_series_co_2_total
# - owd_annual_co_2_emissions_per_country
# - owd_annual_share_of_co_2_emissions
# - owd_carbon_dioxide_emissions_factor
# - owd_co_2_long_term_concentration
# - owd_co_emissions_per_capita
# - owd_cumulative_co_emissions
# - owd_share_of_cumalative_co_2
# - owid_co_2_data

# %% [markdown]
# #6. Catálogo de dados
# A lista de catálogo de dados e os comandos para a execução das tabelas
#
# - catalogo_fontes_dados - tabela de catálogo das fontes de dados
# - catalogo_coluna_dados - tabela de catálogo das colunas com descrição por fontes de dados
# - catalogo_coluna_dados_obs - tabela de catálogo das observação para as colunas
# - catalogo_dados_referencia - tabela de catálogo das referências para as colunas de dados

# %% [markdown]
# ##6.1 Scripts SQL´s
# Abaixo a lista de scripts SQL´s para a criação dos catálogos

# %%
# %sql
--DROP TABLE CATALOGO_FONTES_DADOS;
--DROP TABLE CATALOGO_COLUNA_DADOS;
--DROP TABLE CATALOGO_COLUNA_DADOS_OBS;
--DROP TABLE CATALOGO_DADOS_REFERENCIA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.CATALOGO_PAISES (
  NOME_COMUM STRING,
  NOME_OFICIAL STRING,
  COD_ISO_2 STRING,
  COD_ISO_3 STRING,
  POPULATION NUMERIC,
  REGIAO STRING,
  SUB_REGIAO STRING
);

CREATE TABLE IF NOT EXISTS workspace.pucrio.CATALOGO_FONTES_DADOS(
  ID_FONTE INT NOT NULL,
  NOME_FONTE STRING,
  DESCRICAO_FONTE STRING, 
  URL_FONTE STRING,
  DOCUMENTACAO_DOWNLOAD STRING,
  DATA_CARGA TIMESTAMP  
);

ALTER TABLE workspace.pucrio.CATALOGO_FONTES_DADOS ADD CONSTRAINT PK_CATALOGO_FONTES_DADOS PRIMARY KEY (ID_FONTE);

CREATE TABLE IF NOT EXISTS workspace.pucrio.CATALOGO_COLUNA_DADOS(
  ID_CAMPO INT NOT NULL,
  ID_FONTE INT NOT NULL,
  NOME_COLUNA STRING, 
  DESCRICAO_COLUNA STRING,
  TIPO_DADO STRING,
  CATEGORIA STRING,
  FORMATO_DADO STRING
);

ALTER TABLE workspace.pucrio.catalogo_coluna_dados ADD CONSTRAINT PK_CATALOGO_COLUNA_DADOS PRIMARY KEY (ID_CAMPO);

ALTER TABLE workspace.pucrio.CATALOGO_COLUNA_DADOS ADD CONSTRAINT FK_CATALOGO_COLUNA_DADOS FOREIGN KEY (ID_FONTE) REFERENCES workspace.pucrio.CATALOGO_FONTES_DADOS(ID_FONTE);

CREATE TABLE IF NOT EXISTS workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS (
  ID_OBS INTEGER NOT NULL,
  ID_CAMPO INTEGER NOT NULL,
  OBSERVACAO STRING
);

ALTER TABLE workspace.pucrio.catalogo_coluna_dados_obs ADD CONSTRAINT PK_CATALOGO_COLUNA_DADOS_OBS PRIMARY KEY (ID_OBS);
ALTER TABLE workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS ADD CONSTRAINT FK_CATALOGO_COLUNA_DADOS_OBS FOREIGN KEY (ID_CAMPO) REFERENCES CATALOGO_COLUNA_DADOS(ID_CAMPO);
 
CREATE TABLE IF NOT EXISTS workspace.pucrio.CATALOGO_DADOS_REFERENCIA(
  ID_REFERENCIA INTEGER NOT NULL,
  ID_CAMPO INTEGER,
  NOME_REFERENCIA STRING,
  DESCRICAO_REFERENCIA_ENGLISH STRING,
  DESCRICAO_REFERENCIA_PORTUGUESE STRING
);

ALTER TABLE workspace.pucrio.CATALOGO_DADOS_REFERENCIA ADD CONSTRAINT PK_CATALOGO_DADOS_REFERENCIA PRIMARY KEY (ID_REFERENCIA);

ALTER TABLE workspace.pucrio.CATALOGO_DADOS_REFERENCIA ADD CONSTRAINT FK_CATALOGO_DADOS_REFERENCIA FOREIGN KEY (ID_CAMPO) REFERENCES CATALOG;

--CARBON MONITOR
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(1, 'CARBON_MONITOR', 'Carbon Monitor é um conjunto de dados diários de emissões de CO2 frequentemente atualizado, para monitorizar as variações das emissões de CO2 provenientes da combustão de combustíveis fósseis e da produção de cimento desde 1 de janeiro de 2019 a nível nacional com cobertura quase global.', 'https://datas.carbonmonitor.org/API/downloadFullDataset.php?source=carbon_global', 'A URL disponibilizada já realiza o download automaticamente', current_timestamp());
 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(1, 1, 'Country', 'refere-se ao país da informação', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(2, 1, 'Date', 'refere-se à data que o dado foi coletado', 'DATE', 'DATE', 'DD/MM/YYYY');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(3, 1, 'Sector', 'refere-se ao setor da informação', 'STRING', 'SECTOR', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(4, 1, 'Value', 'refere-se ao valor de CO2 emitidos por dia em metros', 'NUMBER', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(1, 1, 'Há um país no final de cada dia que chama-se WORLD que irá servir para se referir à quantidade de emissão de CO2 no mundo inteiro para o respectivo dia');


--CLIMATE WATCH - AGRICULTURE AREA
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(2, 'CW_AGRICULTURE_AREA', 'O Climate Watch oferece dados abertos - Estas são informações de áreas de agricultura como: plantio, areamento e áreas compartilhadas', 'https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1', '1. Clique em Download Bulk Data
2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
4.1. Data Sources - All Selected
4.2. Parties and Regions - All Selected
4.3. Sectors - All Selected
4.4. Gases - CO2
4.5. Start Year - 1950
4.6. End Year - 2023
4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.
', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(5, 2, 'Area', 'Sigla do país', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(6, 2, 'Short Name', 'nome curto do tipo dado ou sigla do campo nas referências, com referência de valor de: 1000 ha (hectares)', 'STRING', 'SHORT_NAME', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(7, 2, 'Years / Anos', 'estará os valores de anos no restantes das colunas com os dados da quantidade de hectares dividido por 1000 ha', 'NUMBER', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(2, 7, 'As colunas são os anos, por isso o campo Years não tem valor');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(3, 6, 'Short name ou nome curto, é uma referência à um nome de campo que possuí alguma descrição completa na tabela de referências.');

INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(1, 6, 'share_in_agricultural_area_1', 'Arable land', 'Terra arável');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(2, 6, 'share_in_agricultural_area_2', 'Permanent cropland', 'Terras agrícolas permanentes');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(3, 6, 'share_in_agricultural_area_3', 'Permanent meadows and pastures', 'prados e pastagens permanentes');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(4, 6, 'share_in_land_area_1', ' Total Land Area', 'área total do terreno');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(5, 6, 'share_in_land_area_2', 'Share in Land Area', 'área agrícola do terreno compartilhada');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(6, 6, 'share_in_land_area_3', 'Share in Land Area, Other Land', 'outras áreas do terreno compartilhada');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(7, 6, 'share_in_land_area_4', 'Share in Land Area, Forest', 'áreas do terreno compartilhada com florestas'); 


--CLIMATE WATCH - AGRICULTURE EMISSIONS
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES(
3, 'CW_AGRICULTURE_EMISSIONS', 'O Climate Watch oferece dados abertos - intensidade de emissões agrícolas e a referências de valores de: kg CO2eq/kg de produto', 'https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1', '1. Clique em Download Bulk Data
2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
4.1. Data Sources - All Selected
4.2. Parties and Regions - All Selected
4.3. Sectors - All Selected
4.4. Gases - CO2
4.5. Start Year - 1950
4.6. End Year - 2023
4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.', current_timestamp()
);

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(8, 3, 'Area', 'Sigla do país', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(9, 3, 'Short Name', 'nome curto do tipo dado ou sigla do campo nas referências, aqui é para a intensidade de emissões agrícolas e a referências de valores de: kg CO2eq/kg de produto', 'STRING', 'SHORT_NAME', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(10, 3, 'Years / Anos', 'estará os valores de anos no restantes das colunas com os dados da quantidade de kg CO2eq/kg de produto', 'NUMBER', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(4, 10, 'As colunas são os anos, por isso o campo Years não tem valor');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(5, 9, 'Short name ou nome curto, é uma referência à um nome de campo que possuí alguma descrição completa na tabela de referências.');

INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(8, 9, 'emission_intensity_cereals', 'Cereals excluding rice', 'Cereais (excluindo arroz)');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(9, 9, 'emission_intensity_rice', 'Rice paddy', 'arrozal');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(10, 9, 'emission_intensity_meat_cattle', 'Meat cattle', 'Carne de Gado');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(11, 9, 'emission_intensity_meat_goat', ' Meat goat', 'Carne de cabra');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(12, 9, 'emission_intensity_meat_chicken', 'Meat chicken', 'Carne de frango');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(13, 9, 'emission_intensity_meat_pig', 'Meat pig', 'Carne de porcoCarne de porco');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(14, 9, 'emission_intensity_meat_buffalo', 'Meat Buffalo', 'Carne de búfalo'); 
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(14, 9, 'emission_intensity_meat_sheep', 'Meat Sheep', 'Carne de ovelha');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(15, 9, 'emission_intensity_milk_cow', 'Milk Cow', 'Leite de vaca');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(16, 9, 'emission_intensity_milk_goat', 'Milk Goat', 'Leite de cabra');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(17, 9, 'emission_intensity_milk_buffalo', ' Milk Buffalo', 'Leite de búfalo');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(18, 9, 'emission_intensity_milk_sheep', 'Milk Sheep', 'Leite de ovelha');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(19, 9, 'emission_intensity_milk_camel', 'Milk Camel', 'Leite de camelo');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(20, 9, 'emission_intensity_eggs', 'Eggs', 'Ovos'); 


--CLIMATE WATCH - AGRICULTURE EMPLOYEMENT
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(4, 'CW_AGRICULTURE_EMPLOYMENT', 'O Climate Watch oferece dados abertos - para empregados/funcionários/colaboradores nas áreas agrícolas com os valores de referência em percentual', 'https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1', '1. Clique em Download Bulk Data
2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
4.1. Data Sources - All Selected
4.2. Parties and Regions - All Selected
4.3. Sectors - All Selected
4.4. Gases - CO2
4.5. Start Year - 1950
4.6. End Year - 2023
4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.
', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(11, 4, 'Area', 'Sigla do país', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(12, 4, 'Short Name', 'nome curto do tipo dado para empregados/funcionários/colaboradores nas áreas agrícolas com os valores de referência em percentual', 'STRING', 'SHORT_NAME', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(13, 4, 'Years / Anos', 'estará os valores de anos no restantes das colunas com os dados percentuais', 'NUMBER', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(7, 12, 'Short name ou nome curto, é uma referência à um nome de campo que possuí alguma descrição completa na tabela de referências.');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(6, 13, 'As colunas são os anos, por isso o campo Years não tem valor');

INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(11, 12, 'employment_agri_female', '% of female employment', 'porcentagem de mulheres trabalhando na área agrícola');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(12, 12, 'employment_agri_male', '% of male employment', 'porcentagem de homens trabalhando na área agrícola');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(13, 12, 'employment_agri_total', '% of total employment', 'porcentagem de total trabalhando na área agrícola');



--CLIMATE WATCH - MEAT CONSUMPTION
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(5, 'CW_AGRICULTURE_MEAT_CONSUMPTION', 'O Climate Watch oferece dados abertos - consumo de carne com os valores de referência em: 1000 t (toneladas) ou quilogramas per capita', 'https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1', '1. Clique em Download Bulk Data
2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
4.1. Data Sources - All Selected
4.2. Parties and Regions - All Selected
4.3. Sectors - All Selected
4.4. Gases - CO2
4.5. Start Year - 1950
4.6. End Year - 2023
4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.
', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(14, 5, 'Area', 'Sigla do país', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(15, 5, 'Short Name', 'nome curto do tipo dado para de consumo de carne com os valores de referência em: 1000 t (toneladas) ou quilogramas per capita', 'STRING', 'SHORT_NAME', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(16, 5, 'Years / Anos', 'estará os valores de anos no restantes das colunas com os dados percentuais', 'NUMBER', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(8, 15, 'Short name ou nome curto, é uma referência à um nome de campo que possuí alguma descrição completa na tabela de referências.');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(9, 16, 'As colunas são os anos, por isso o campo Years não tem valor');

INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(14, 15, 'meat_consumption_1', 'Beef', 'carne de gado');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(15, 15, 'meat_consumption_2', 'Pork', 'carne de porco');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(16, 15, 'meat_consumption_3', 'Poultry', 'carne de aves');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(17, 15, 'meat_consumption_4', 'Sheep', 'carne de ovelha');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(18, 15, 'meat_consumption_per_capita_1', 'Beef', 'carne de gado');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(19, 15, 'meat_consumption_per_capita_2', 'Pork', 'carne de porco');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(20, 15, 'meat_consumption_per_capita_3', 'Poultry', 'carne de aves');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(21, 15, 'meat_consumption_per_capita_4', 'Sheep', 'carne de ovelha');


--CLIMATE WATCH - PESTICIDES FERTILIZERS
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(6, 'CW_AGRICULTURE_PESTICIDES_FERTILIZERS', 'O Climate Watch oferece dados abertos - tipo de fertilizante, herbicida, pesticida e outros agrotóxicos que podem influenciar nos alimentostipo de fertilizante, herbicida, pesticida e outros agrotóxicos que podem influenciar nos alimentos', 'https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1', '1. Clique em Download Bulk Data
2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
4.1. Data Sources - All Selected
4.2. Parties and Regions - All Selected
4.3. Sectors - All Selected
4.4. Gases - CO2
4.5. Start Year - 1950
4.6. End Year - 2023
4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.
', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(17, 6, 'Area', 'Sigla do país', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(18, 6, 'Short Name', 'Código do FAOSTAT, que condiz o tipo de fertilizante, herbicida, pesticida e outros agrotóxicos que podem influenciar nos alimentos, conforme a Organização Mundial de Alimentos e Agricultura das Nações Unidas (fonte: https://www.fao.org/home/en)', 'STRING', 'SHORT_NAME', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(19, 6, 'Years / Anos', 'estará os valores de anos no restantes das colunas com os dados em toneladas', 'NUMBER', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(10, 18, 'Short name ou nome curto, é uma referência à um nome de campo que possuí alguma descrição completa na tabela de referências.');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(11, 19, 'As colunas são os anos, por isso o campo Years não tem valor');

INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(22, 15, 'total_fertilizers', 'Total Fertilizers', 'Uso total de fertilizantes na agricultura (N, P2O5, K2O)');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(23, 15, 'total_pesticides_use', 'Total pesticides', 'Uso total de pesticidas');


--CLIMATE WATCH - PRODUCTION TRADE
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(7, 'CW_AGRICULTURE_PRODUCTION_TRADE', 'O Climate Watch oferece dados abertos - comércio e produção de produtos agrícolas, importação e exportação', 'https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1', '1. Clique em Download Bulk Data
2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
4.1. Data Sources - All Selected
4.2. Parties and Regions - All Selected
4.3. Sectors - All Selected
4.4. Gases - CO2
4.5. Start Year - 1950
4.6. End Year - 2023
4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.
', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(20, 7, 'Area', 'Sigla do país', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(21, 7, 'Short Name', 'Código do FAOSTAT, que condiz o tipo de fertilizante, herbicida, pesticida e outros agrotóxicos que podem influenciar nos alimentos, conforme a Organização Mundial de Alimentos e Agricultura das Nações Unidas (fonte: https://www.fao.org/home/en)', 'STRING', 'SHORT_NAME', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(22, 7, 'Years / Anos', 'estará os valores de anos no restantes das colunas com os dados em toneladas', 'NUMBER', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(12, 21, 'Short name ou nome curto, é uma referência à um nome de campo que possuí alguma descrição completa na tabela de referências.');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(13, 22, 'As colunas são os anos, por isso o campo Years não tem valor');

INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(24, 21, 'production_Agr_1', 'Agriculture Prouction - Maize', 'produção agrícola de milho');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(25, 21, 'production_Agr_2', 'Agriculture Prouction - Rice', 'produção agrícola de arroz');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(26, 21, 'production_Agr_3', 'Agriculture Prouction - Soy', 'produção agrícola de soja');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(27, 21, 'production_Agr_4', 'Agriculture Prouction - Wheat', 'produção agrícola de trigo');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(28, 21, 'production_Agr_5', 'Agriculture Prouction - Cattle', 'produção agrícola de gado');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(29, 21, 'production_Agr_6', 'Agriculture Prouction - Pig', 'produção agrícola de porco');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(30, 21, 'production_Agr_7', 'Agriculture Prouction - Chicken', 'produção agrícola de frango');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(31, 21, 'production_Agr_8', 'Agriculture Prouction - Goat', 'produção agrícola de ovelha');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(32, 21, 'production_Agr_9', 'Agriculture Prouction - Milk Cow', 'produção agrícola de leite de vaca');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(33, 21, 'production_Agr_10', 'Agriculture Prouction - Milk Goat', 'produção agrícola de leite de cabra');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(34, 21, 'trade_export_1', 'Trade of agriculture commodities - Export - Rice', 'Comércio de produtos agrícolas exportação de arroz');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(35, 21, 'trade_export_2', 'Trade of agriculture commodities - Export - Wheat', 'Comércio de produtos agrícolas exportação de trigo');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(36, 21, 'trade_export_3', 'Trade of agriculture commodities - Export - Soybeans', 'Comércio de produtos agrícolas exportação de soja');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(37, 21, 'trade_export_4', 'Trade of agriculture commodities - Export - Maize', 'Comércio de produtos agrícolas exportação de milho');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(38, 21, 'trade_export_5', 'Trade of agriculture commodities - Export - Milk Cow', 'Comércio de produtos agrícolas exportação de leite de vaca');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(39, 21, 'trade_export_6', 'Trade of agriculture commodities - Export - Chicken', 'Comércio de produtos agrícolas exportação de frango');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(40, 21, 'trade_export_7', 'Trade of agriculture commodities - Export - Goat', 'Comércio de produtos agrícolas exportação de cabra');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(41, 21, 'trade_export_8', 'Trade of agriculture commodities - Export - Pig', 'Comércio de produtos agrícolas exportação de porco');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(42, 21, 'trade_import_1', 'Trade of agriculture commodities - Import - Rice', 'Comércio de produtos agrícolas importação de arroz');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(43, 21, 'trade_import_2', 'Trade of agriculture commodities - Import - Wheat', 'Comércio de produtos agrícolas importação de trigo');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(44, 21, 'trade_import_3', 'Trade of agriculture commodities - Import - Soybeans', 'Comércio de produtos agrícolas importação de soja');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(45, 21, 'trade_import_4', 'Trade of agriculture commodities - Import - Maize', 'Comércio de produtos agrícolas importação de milho');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(46, 21, 'trade_import_5', 'Trade of agriculture commodities - Import - Milk Cow', 'Comércio de produtos agrícolas importação de leite de vaca');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(47, 21, 'trade_import_6', 'Trade of agriculture commodities - Import - Chicken', 'Comércio de produtos agrícolas importação de frango');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(48, 21, 'trade_import_7', 'Trade of agriculture commodities - Import - Goat', 'Comércio de produtos agrícolas importação de cabra');
INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(49, 21, 'trade_import_8', 'Trade of agriculture commodities - Import - Pig', 'Comércio de produtos agrícolas importação de porco');


--CLIMATE WATCH - AGRICULTURE VALUE ADDED
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(8, 'CW_AGRICULTURE_VALUE_ADDED', 'O Climate Watch oferece dados abertos - valor adicionado (agricultura) em porcentagem do PIB', 'https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1', '1. Clique em Download Bulk Data
2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
4.1. Data Sources - All Selected
4.2. Parties and Regions - All Selected
4.3. Sectors - All Selected
4.4. Gases - CO2
4.5. Start Year - 1950
4.6. End Year - 2023
4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.
', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(23, 8, 'Area', 'Sigla do país', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(24, 8, 'Short Name', 'nome curto do tipo do dado para o valor adicionado (agricultura) em porcentagem do PIB', 'STRING', 'SHORT_NAME', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(25, 8, 'Years / Anos', 'estará os valores de anos no restantes das colunas com os dados percentuais', 'NUMBER', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(14, 23, 'Short name ou nome curto, é uma referência à um nome de campo que possuí alguma descrição completa na tabela de referências.');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(15, 24, 'As colunas são os anos, por isso o campo Years não tem valor');

INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(50, 24, 'value_added_Agr', 'Aggregate value', 'valor agregado do PIB em porcentagem');


--CLIMATE WATCH - AGRICULTURE WATER
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(9, 'CW_AGRICULTURE_VALUE_ADDED', 'O Climate Watch oferece dados abertos - retirada de água total para áreas agrícolas', 
'https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1',
'1. Clique em Download Bulk Data
2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
4.1. Data Sources - All Selected
4.2. Parties and Regions - All Selected
4.3. Sectors - All Selected
4.4. Gases - CO2
4.5. Start Year - 1950
4.6. End Year - 2023
4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.
', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(23, 9, 'Area', 'Sigla do país', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(24, 9, 'Short Name', 'nome curto do tipo do dado para o percentual de retirada de água total para áreas agrícolas', 'STRING', 'SHORT_NAME', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(25, 9, 'Years / Anos', 'estará os valores de anos no restantes das colunas com os dados em percentuais', 'NUMBER', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(14, 26, 'Short name ou nome curto, é uma referência à um nome de campo que possuí alguma descrição completa na tabela de referências.');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(15, 27, 'As colunas são os anos, por isso o campo Years não tem valor');

INSERT INTO workspace.pucrio.catalogo_dados_referencia VALUES
(50, 24, 'water_withdrawal', 'Agricultural water withdrawal as % of total water withdrawal', 'Retirada de água para agricultura como % da retirada total de água');



--CLIMATE WATCH - Historical Emissions
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(10, 'CW_HISTORICAL_EMISSIONS', 'O Climate Watch oferece dados abertos - histórico quantidade de emissão de dióxido de carbono', 'https://www.climatewatchdata.org/data-explorer/historical-emissions?historical-emissions-data-sources=climate-watch&historical-emissions-gases=all-ghg&historical-emissions-regions=All%20Selected&historical-emissions-sectors=total-including-lulucf&page=1', '1. Clique em Download Bulk Data
2. Baixe dois arquivos, sendo eles: Agriculture Profile e GHG Emissions
3. Ao clicar nos links das fontes de dados será direcionado para um cadastro de newslatter, bem simples, basta preencher o cadastro e o download será iniciado.
4. Ainda na tela de historical emissions, faça os seguintes filtros para realizar o donwload de todo o histórico de emissões de gás de dióxido de carbono:
4.1. Data Sources - All Selected
4.2. Parties and Regions - All Selected
4.3. Sectors - All Selected
4.4. Gases - CO2
4.5. Start Year - 1950
4.6. End Year - 2023
4.7. Bem abaixo do gráfico há um botão chamado: Download Historical Data, clique para realizar o download.
', current_timestamp());
 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(26, 10, 'country', 'Sigla do país', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(27, 10, 'source', 'fonte para o dado obtido tecnologia que realizou a coleta de dados, nesse arquivo terá duas, sendo elas: UNFCCC_AI (por inteligência artificial) e UNFCCC_NAI (Refere-se aos países que não estão listados no Anexo I da Convenção-Quadro das Nações Unidas)', 'STRING', 'SOURCE', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(28, 10, 'sector', 'Setor da emissão do gás que o dado está sendo verificado', 'STRING', 'SECTOR', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(29, 10, 'Gas', 'tipo do gás que está sendo verificado no dado', 'STRING', 'GAS', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(30, 10, 'Years / Anos', 'estará os valores de anos no restantes das colunas com os dados dos valores em MtCO₂e (milhões de toneladas de dióxido de carbono equivalente).', 'FLOAT', 'VALUE', 
'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(16, 26, 'Há dados com os valores de country (países) com a seguinte informação: ANNEXI, talvez seja o valor do arquivo para o planeta, pois não há essa Contry no arquivo, ao contrário dos demais arquivos, entretanto também não há evidências suficiente para afirmar isso, então, esses campos serão descartados.');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(17, 27, 'Os valores do source também serão descartados, afinal não é interessante para essa pesquisa.');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(18, 28, 'Há alguns setores que possuem valores agregados para vários tipos de gases, e outros de tipos de pesquisas que estão juntos, como o objetivo deste projeto é apenas de dióxido de carbono, estes valores serão descartados.');


--International Energy Agency (IEA) - gases emissions
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(11, 'IEA_GAS_EMISSIONS', 'International Energy Agency (IEA) - histórico de emissão de dióxido de carbono por tipos de gases', 'https://www.iea.org/data-and-statistics/data-product/global-energy-review-co2-emissions-in-2021#', 'Link para download direto, onde será um arquivo XLSX e terá que fazer um cadastro gratuito no site para conseguir realizar o download da fonte de dados', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(31, 11, 'Type emission', 'Tipo de emissão', 'STRING', 'SECTOR', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(32, 11, 'CO2 emissions', 'origem de emissão de CO2', 'STRING', 'ORIGIN', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(33, 11, 'Unit', 'unidade de medida da emissão de CO2', 'STRING', 'UNIT', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(34, 11, 'Year', 'ano da emissão de CO2 conforme a unidade de medida', 'STRING', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(35, 11, 'Grow rate % Year', 'taxa de variação em porcentagem entre os anos 1 e 2, 2 e 3', 'FLOAT', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');
 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(19, 34, 'As colunas são os anos, por isso o campo Years não tem valor');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(20, 35, 'As colunas são os anos, por isso o campo Years não tem valor');


--International Energy Agency (IEA) - coutries
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(12, 'IEA_EMISSIONS', 'International Energy Agency (IEA) - histórico de emissão de dióxido de carbono por países', 
'https://www.iea.org/data-and-statistics/data-product/global-energy-review-co2-emissions-in-2021#', 
'Link para download direto, onde será um arquivo XLSX e terá que fazer um cadastro gratuito no site para conseguir realizar o download da fonte de dados', 
current_timestamp()); 

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(36, 12, 'Type emission', 'Tipo de emissão', 'STRING', 'SECTOR', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(37, 12, 'country', 'país de emissão de CO2', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(38, 12, 'Unit', 'unidade de medida da emissão de CO2', 'STRING', 'UNIT', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(39, 12, 'Year', 'ano da emissão de CO2 conforme a unidade de medida', 'STRING', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(40, 12, 'Grow rate % Year', 'taxa de variação em porcentagem entre os anos 1 e 2, 2 e 3', 'FLOAT', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');
 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(21, 39, 'As colunas são os anos, por isso o campo Years não tem valor');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(22, 40, 'As colunas são os anos, por isso o campo Years não tem valor');


--Food And Agriculture Organization of the United Nations
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(13, 'FAOSTAT_EMISSIONS_TOTALS', 'Food And Agriculture Organization of the United Nations - Organização de comida e agricultura das nações unidas
- Informações sobre tipos de alimentos, ano e tipos de gases emitidos', 'https://www.iea.org/data-and-statistics/data-product/global-energy-review-co2-emissions-in-2021#', 'Link para download direto, onde será um arquivo XLSX e terá que fazer um cadastro gratuito no site para conseguir realizar o download da fonte de dados', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(41, 13, 'Area Code', 'código da área', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(42, 13, 'Area code M49', 'código da área conforme a tabela M49', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(43, 13, 'Area', 'Nome do país ou da área do registro', 'STRING', 'COUNTRY', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(44, 13, 'Item Code', 'código dos itens', 'STRING', 'ITEM', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(45, 13, 'Item', 'Nome do item', 'STRING', 'ITEM', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(46, 13, 'Element Code', 'Código do elemento do registro e/ou da emissão', 'STRING', 'ELEMENT', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(47, 13, 'Element', 'nome do elemento do registro', 'STRING', 'ELEMENT', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(48, 13, 'Source Code', 'código da fonte de dados', 'STRING', 'SOURCE', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(49, 13, 'Source', 'fonte dos dados', 'STRING', 'SOURCE', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(50, 13, 'unit', 'unidade de medida do elemento', 'STRING', 'UNIT', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(51, 13, 'Years', 'campos com os Anos', 'FLOAT', 'VALUE', 'ZZZ.ZZZ.ZZ9,999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(23, 41, 'Coluna descartada por se tratar de um código que não está totalmente tratado no arquivo de origem');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(24, 42, 'Coluna descartada por se tratar de um código que não está totalmente tratado no arquivo de origem');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(25, 44, 'Coluna descartada por se tratar de um código que não está totalmente tratado no arquivo de origem');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(26, 46, 'Coluna descartada por se tratar de um código que não está totalmente tratado no arquivo de origem');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(27, 48, 'Coluna descartada por se tratar de um código que não está totalmente tratado no arquivo de origem');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(28, 49, 'Coluna descartada por se tratar de um código que não está totalmente tratado no arquivo de origem');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(29, 51, 'arquivo com flags: Y - representando o ano, o número do ano no formato YYYY - X - Letra da Flag, ficando da seguinte forma: Y2025X');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(30, 51, 'no arquivo que possuí as flags, há anos que possuem a flag: N, entretanto não há informações sobre esta flag no arquivo e flags, então por este motivo foi optado por usar o arquivo NOFLAG');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(31, 52, 'o arquivo NOFLAG possuí apenas o Y seguido do ano em 4 dígitos (Ex.: Y2025)');



--NASA
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(14, 'NASA_CMS_FLUX_TOTAL', 'National Aeronautics and Space Administration (NASA) - Mostra os dados de fluxo de carbono total em uma área por latitude e longitude.', 'https://acdisc.gsfc.nasa.gov/data/CMS/CMSFluxTotal.3', '1. Os passos para download são:
1. Clique em Once Registered, you can click here.
2. Caso não tenha um cadastro, crie um.
3. Depois realize o login
4. Volte na página do link direto para download
5. Clique no arquivo CMSFluxTotal201001_202212_v3.nc
6. Baixe o arquivo.
7. Execute o comando em Python para converter arquivos NC para CSV.
', current_timestamp()
);

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(52, 14, 'Time', 'Data e hora da coleta dos dados, no formato: YYYY-MM-DD HH:MM:SS', 'STRING', 'YEAR', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(53, 14, 'latitude', 'é os graus de latitude do registro', 'STRING', 'LOCAL', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(54, 14, 'longitude', 'é os graus de longitude do registro', 'STRING', 'LOCAL', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(55, 14, 'total_post', 'quantidade de CO2 emitido na área em g/m^2/day (gramas por metro quadrado por dia)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(56, 14, 'area', 'é a área em m2 (metros quadrados)', 'FLOAT', 'AREA', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(32, 52, 'Agrupada o tempo em ano');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(33, 53, 'Agrupada junto com longitude e separado por "," (Vírgula)');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(34, 54, 'Agrupada junto com latitude e separado por "," (Vírgula)');



--ONU - NAÇÕES UNIDAS --EMISSIONS REMOVALS
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(15, 'ONU_ANNUAL_EMISSIONS_REMOVALS', 'Organização das Nações Unidas (ONU) - CO2 total with LULUCF (Uso da Terra, Mudança no Uso da Terra e Florestas).
', 'https://di.unfccc.int/time_series', '1. São vários datasets e conforme vai navegando poderá ir baixando os dados, exemplo, se clicar em Flexible Queries > Preencher todas as informações relacionadas à carbbono (em inglês Carbon) ou CO² mostrará então um relatório em tabela para exportar para CSV, ou em Time Series - Annex I, poderá ir filtrando as informações relacionadas com estas palavras-chaves e então modificando o resultado da consulta da tabela, e com isso exportar para XLSX e posteriormente converter para CSV.
', current_timestamp());
 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(57, 15, 'Category', 'Categoria do setor de emissão', 'STRING', 'SECTOR', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(58, 15, 'Base year', 'ano base', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(59, 15, 'Campos de anos', 'Campos de anos', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(60, 15, 'Last inventory Year (2021)', 'ano de 2021 que foi a última coleta', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');


--ONU - NAÇÕES UNIDAS -- GREENHOUSE GAS
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(16, 'ONU_ANNUAL_GREENHOUSE_GAS', 'Organização das Nações Unidas (ONU) - Emissões de gases do efeito estufa anuais.', 
'https://di.unfccc.int/detailed_data_by_party', 
'1. São vários datasets e conforme vai navegando poderá ir baixando os dados, exemplo, se clicar em Flexible Queries > Preencher todas as informações relacionadas à carbbono (em inglês Carbon) ou CO² mostrará então um relatório em tabela para exportar para CSV, ou em Time Series - Annex I, poderá ir filtrando as informações relacionadas com estas palavras-chaves e então modificando o resultado da consulta da tabela, e com isso exportar para XLSX e posteriormente converter para CSV.
2. Select Party - Annex I
3. Select Base Year - All Years
4. Select Totals - Total GHG emissions with LULUCF
5. Select Aggregate GHGs - CO2
6. Select kt - kt
', current_timestamp()
);

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(61, 16, 'Category', 'Categoria do setor de emissão', 'STRING', 'SECTOR', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(62, 16, 'Base year', 'ano base', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(63, 16, 'Campos de anos', 'Campos de anos', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(64, 16, 'Last inventory Year (2021)', 'ano de 2021 que foi a última coleta', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(65, 16, 'Change from base yar to latest reported year', 'comparativo entre a última coleta e a coleta base', 'FLOAT', 'AREA', 'ZZZ,ZZZ,ZZ9.999');


--ONU - NaÇÕES UNIDAS -- EMISSÕES TOTAIS DE CO2 POR ANO
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(17, 'ONU_TIME_SERIES_CO_2_TOTAL', 'Organização das Nações Unidas (ONU) - Emissões totais de CO2 por ano', 
'https://di.unfccc.int/flex_annex1', 
'1. São vários datasets e conforme vai navegando poderá ir baixando os dados, exemplo, se clicar em Flexible Queries > Preencher todas as informações relacionadas à carbbono (em inglês Carbon) ou CO² mostrará então um relatório em tabela para exportar para CSV, ou em Time Series - Annex I, poderá ir filtrando as informações relacionadas com estas palavras-chaves e então modificando o resultado da consulta da tabela, e com isso exportar para XLSX e posteriormente converter para CSV.
2. Select Party - Annex I
3. Select Base Year - All Years
4. Select Totals - Total GHG emissions with LULUCF
5. Select Total for category
6. Select Type of valye: Net emiissions/removals
7. Select kt - kt
', current_timestamp()
);

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(66, 17, 'Category', 'Categoria do setor de emissão', 'STRING', 'SECTOR', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(67, 17, 'Base year', 'ano base', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(68, 17, 'Campos de anos', 'Campos de anos', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(69, 17, 'Last inventory Year (2021)', 'ano de 2021 que foi a última coleta', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');



--OUR WORLD IN DATA - EMISSÕES TOTAIS DE CO2 POR PAÍSES
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(18, 'OWD_ANNUAL_CO_2_EMISSIONS_PER_COUNTRY', 'Our World in Data - Emissões totais de CO2 por país', 'https://ourworldindata.org/search?q=co2', '3.7.2. Pesquisar por CO2 irá ser mostrada as seguintes informações, realizar download das informações abaixo
1. CO2 emissions per capita
2. Annual CO2 emissions
3. Annual concentration of atmospheric carbon dioxide
4. Annual CO2 emissions by world region
5. Share of global CO2 emissions
6. Cumulative CO2 emissions
7. Cumulative CO2 emissions by world region
8. Share of global cumulative CO₂ emissions
9. Carbon dioxide emissions factors
', current_timestamp()
);

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(70, 18, 'Entity', 'País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(71, 18, 'Code', 'Sigla do País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(72, 18, 'Year', 'Campos de anos', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(73, 18, 'Annual CO2 Emissions', 'valor anual de emissão de CO2', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(35, 70, 'Há um país chamado WORLD ou mundo para agregar tudo');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(36, 73, 'Os valores de referência estão em toneladas.'); 

 
--OUR WORLD IN DATA - Emissões totais de CO2 de áreas compartilhadas
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(19, 'OWD_ANNUAL_SHARE_OF_CO_2_EMISSIONS', 'Our World in Data - Emissões totais de CO2 de áreas compartilhadas', 'https://ourworldindata.org/search?q=co2', '3.7.2. Pesquisar por CO2 irá ser mostrada as seguintes informações, realizar download das informações abaixo
1. CO2 emissions per capita
2. Annual CO2 emissions
3. Annual concentration of atmospheric carbon dioxide
4. Annual CO2 emissions by world region
5. Share of global CO2 emissions
6. Cumulative CO2 emissions
7. Cumulative CO2 emissions by world region
8. Share of global cumulative CO₂ emissions
9. Carbon dioxide emissions factors
', current_timestamp()
);

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(74, 19, 'Entity', 'País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(75, 19, 'Code', 'Sigla do País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(76, 19, 'Year', 'Campos de anos', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(77, 19, 'Annual CO2 Emissions', 'valor anual de emissão de CO2', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(37, 74, 'Há um país chamado WORLD ou mundo para agregar tudo');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(38, 77, 'Os valores de referência estão em toneladas.'); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(39, 74, 'Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.');

 

--OUR WORLD IN DATA - Fatores de emissão de carbono
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(20, 'OWD_CARBON_DIOXIDE_EMISSIONS_FACTOR', 'Our World in Data - Fatores de emissão de carbono', 'https://ourworldindata.org/search?q=co2', '3.7.2. Pesquisar por CO2 irá ser mostrada as seguintes informações, realizar download das informações abaixo
1. CO2 emissions per capita
2. Annual CO2 emissions
3. Annual concentration of atmospheric carbon dioxide
4. Annual CO2 emissions by world region
5. Share of global CO₂ emissions
6. Cumulative CO2 emissions
7. Cumulative CO2 emissions by world region
8. Share of global cumulative CO₂ emissions
9. Carbon dioxide emissions factors
', current_timestamp()
);

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(78, 20, 'Entity', 'País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(79, 20, 'Code', 'Sigla do País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(80, 20, 'Year', 'Campos de anos', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(81, 20, 'Annual CO2 Emissions', 'CO2 emission factor - valor da emissão de CO2 do fator', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(40, 78, 'Há um país chamado WORLD ou mundo para agregar tudo');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(41, 80, 'Os valores de referência estão em toneladas.'); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(42, 78, 'Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.');

 

 
--OUR WORLD IN DATA - Concentração longo prazo de CO2
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(21, 'OWD_CO_2_LONG_TERM_CONCENTRATION', 'Our World in Data - Concentração longo prazo de CO2', 'https://ourworldindata.org/search?q=co2', '3.7.2. Pesquisar por CO2 irá ser mostrada as seguintes informações, realizar download das informações abaixo
1. CO2 emissions per capita
2. Annual CO2 emissions
3. Annual concentration of atmospheric carbon dioxide
4. Annual CO2 emissions by world region
5. Share of global CO2 emissions
6. Cumulative CO2 emissions
7. Cumulative CO2 emissions by world region
8. Share of global cumulative CO₂ emissions
9. Carbon dioxide emissions factors
', current_timestamp()
);

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(82, 21, 'Entity', 'País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(83, 21, 'Code', 'Sigla do País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(84, 21, 'Year', 'quantidade de concentração anual de dióxido de carbono na atmosfera', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(85, 21, 'Annual CO2 Emissions', 'CO2 emission factor - valor da emissão de CO2 do fator', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(43, 82, 'Há apenas o país chamado WORLD ou mundo para agregar tudo');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(44, 85, 'Os valores de referência estão em toneladas.'); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(46, 85, 'Há mais da metade dos registros que estão com o valor de ano em negativo, e um valor bem estranho, exemplo: -803719');

 


--OUR WORLD IN DATA - Emissões totais de CO2 por capita
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(22, 'OWD_CO_EMISSIONS_PER_CAPITA', 'Our World in Data - Emissões totais de CO2 por capita', 'https://ourworldindata.org/search?q=co2', '3.7.2. Pesquisar por CO2 irá ser mostrada as seguintes informações, realizar download das informações abaixo
1. CO2 emissions per capita
2. Annual CO2 emissions
3. Annual concentration of atmospheric carbon dioxide
4. Annual CO2 emissions by world region
5. Share of global CO2 emissions
6. Cumulative Co2 emissions
7. Cumulative CO2 emissions by world region
8. Share of global cumulative CO₂ emissions
9. Carbon dioxide emissions factors
', current_timestamp());

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(86, 22, 'Entity', 'País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(87, 22, 'Code', 'Sigla do País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(88, 22, 'Year', 'quantidade de CO2 emitido per capita', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(89, 22, 'Annual CO2 Emissions (per_capita)', 'quantidade de CO2 emitido per capita', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(47, 86, 'Há apenas o país chamado WORLD ou mundo para agregar tudo');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(48, 89, 'Os valores de referência estão em toneladas.'); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(49, 86, 'Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.');

 


--OUR WORLD IN DATA - Emissões totais acumuladas de CO2
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(23, 'OWD_CUMULATIVE_CO_EMISSIONS', 'Our World in Data - Emissões totais acumuladas de CO2', 'https://ourworldindata.org/search?q=co2', '3.7.2. Pesquisar por CO2 irá ser mostrada as seguintes informações, realizar download das informações abaixo
1. CO2 emissions per capita
2. Annual CO2 emissions
3. Annual concentration of atmospheric carbon dioxide
4. Annual CO2 emissions by world region
5. Share of global CO2 emissions
6. Cumulative CO2 emissions
7. Cumulative CO2 emissions by world region
8. Share of global cumulative CO₂ emissions
9. Carbon dioxide emissions factors
', current_timestamp()
);


INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(90, 23, 'Entity', 'País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(90, 23, 'Code', 'Sigla do País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(91, 23, 'Year', 'quantidade de CO2 emitido per capita', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(92, 23, 'Cumulative CO2 emissions', 'quantidade acumulada ao longo dos anos de emissão de CO2', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(50, 90, 'Há apenas o país chamado WORLD ou mundo para agregar tudo');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(51, 92, 'Os valores de referência estão em toneladas.'); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(52, 90, 'Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.');

 


--OUR WORLD IN DATA - Acumulado de emissões de CO2 em áreas compartilhadas
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(24, 'OWD_SHARE_OF_CUMULATIVE_CO_2', 'Our World in Data - Acumulado de emissões de CO2 em áreas compartilhadas', 'https://ourworldindata.org/search?q=co2', '3.7.2. Pesquisar por CO2 irá ser mostrada as seguintes informações, realizar download das informações abaixo
1. CO2 emissions per capita
2. Annual CO2 emissions
3. Annual concentration of atmospheric carbon dioxide
4. Annual CO2 emissions by world region
5. Share of global CO2 emissions
6. Cumulative CO2 emissions
7. Cumulative CO2 emissions by world region
8. Share of global cumulative CO₂ emissions
9. Carbon dioxide emissions factors
', current_timestamp()
);


INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(91, 24, 'Entity', 'País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(92, 24, 'Code', 'Sigla do País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(93, 24, 'Year', 'quantidade de CO2 emitido per capita', 'STRING', 'YEAR', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(94, 24, 'Share of global cumulative CO2 emissions ', 'emissão de CO2 acumulada de áreas compartilhadas', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');

INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(53, 91, 'Há apenas o país chamado WORLD ou mundo para agregar tudo');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(54, 94, 'Os valores de referência estão em toneladas.'); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(55, 91, 'Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.');

 

--OUR WORLD IN DATA - Dados gerais de emisisões de dióxido de carbono
INSERT INTO workspace.pucrio.CATALOGO_FONTES_DADOS VALUES 
(25, 'OWID_CO_2_DATA', 'Our World in Data - Dados gerais de emisisões de dióxido de carbono', 'https://ourworldindata.org/search?q=co2', '3.7.2. Pesquisar por CO2 irá ser mostrada as seguintes informações, realizar download das informações abaixo
1. CO2 emissions per capita
2. Annual CO2 emissions
3. Annual concentration of atmospheric carbon dioxide
4. Annual CO2 emissions by world region
5. Share of global CO2 emissions
6. Cumulative CO2 emissions
7. Cumulative CO2 emissions by world region
8. Share of global cumulative CO2 emissions
9. Carbon dioxide emissions factors
', current_timestamp()
);


INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(95, 25, 'Country', 'País', 'STRING', 'COUNTRY', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(96, 25, 'Year', 'Ano', 'STRING', 'Year', '');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(97, 25, 'ISO_CODE', 'Sigla do País', 'STRING', 'COUNTRY', ''); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(98, 25, 'Population', 'População', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(99, 25, 'gdp', 'Gross domestic product (GDP) - Produção econômica total de um país ou região por ano', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(100, 25, 'cement_co2', ' Annual CO2 emissions from cement - Emissões anuais de dióxido de carbono (CO2) provenientes do cimento', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(101, 25, 'cement_co2_per_capita', 'Annual CO2 emissions from cement (per capita) - Emissões anuais de dióxido de carbono (CO2) provenientes do cimento per capita', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(102, 25, 'co2', 'Annual CO2 - Emissão de CO2 anual', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(103, 25, 'co2_growth_abs', 'Annual CO2 emissions growth (abs) - Crescimento anual das emissões de CO2 (absoluto)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999'); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(104, 25, 'co2_growth_prct', 'Annual CO2 emissions growth (%) - Crescimento anual das emissões de CO2 (%)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(105, 25, 'co2_including_luc', 'Annual CO2 emissions including land-use change - Emissões anuais de CO2, incluindo mudanças no uso da terra.', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(106, 25, 'co2_including_luc_growth_abs', 'Growth rate of emissions including land-use change - Taxa de crescimento das emissões, incluindo mudanças no uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(107, 25, 'co2_including_luc_growth_prct', 'Growth rate of emissions including land-use change (%) - Taxa de crescimento das emissões, incluindo mudanças no uso da terra (%)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(108, 25, 'co2_including_luc_per_capita', 'Annual CO2 emissions including land-use change per capita - Emissões anuais de CO2, incluindo mudanças no uso da terra (por pessoa)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(109, 25, 'co2_including_luc_per_gdp', 'Annual CO2 emissions including land-use change per GDP - Emissões anuais de CO2, incluindo mudanças no uso da terra (por PIB)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(110, 25, 'co2_including_luc_per_unit_energy', 'Annual CO2 emissions including land-use change per unit energy - Emissões anuais de CO2, incluindo mudanças no uso da terra (por unidade de energia)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(111, 25, 'co2_per_capita', 'CO2 emissions per capita - Emissões de CO2 por pessoa', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(112, 25, 'co2_per_gdp', 'Annual CO2 emissions per GDP (kg per international-$) - Emissões anuais de CO2 por PIB (kg por dólar internacional)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(113, 25, 'co2_per_unit_energy', 'Annual CO2 emissions per unit energy (kg per kilowatt-hour) - Emissões anuais de CO2 por unidade de energia (kg por quilowatt-hora)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(114, 25, 'coal_co2', 'Annual CO2 emissions from coal - Emissões anuais de CO2 do carvão', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(115, 25, 'coal_co2_per_capita', 'Annual CO2 emissions from coal (per capita) - Emissões anuais de CO2 do carvão (por pessoa)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(116, 25, 'consumption_co2', 'Annual consumption-based CO2 emissions - Emissões anuais de CO2 baseadas no consumo', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(117, 25, 'consumption_co2_per_capita', 'Per capita consumption-based CO2 emissions - Emissões de CO2 baseadas no consumo (por pessoa)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(118, 25, 'consumption_co2_per_gdp', 'Annual consumption-based CO2 emissions per GDP (kg per international-$) - Emissões anuais de CO2 baseadas no consumo (por PIB)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(119, 25, 'cumulative_cement_co2', 'Cumulative CO2 emissions from cement - Emissões acumuladas de CO2 do cimento', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(120, 25, 'cumulative_co2', 'Cumulative CO2 emissions - Emissões acumuladas de CO2', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(121, 25, 'cumulative_co2_including_luc', 'Cumulative CO2 emissions including land-use change - Emissões acumuladas de CO2, incluindo mudanças no uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999'); 
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(122, 25, 'cumulative_coal_co2', 'Cumulative CO2 emissions from coal - Emissões acumuladas de CO2 do carvão', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(123, 25, 'cumulative_flaring_co2', 'Cumulative CO2 emissions from flaring - Emissões acumuladas de CO2 da queima de gás', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(124, 25, 'cumulative_gas_co2', 'Cumulative CO2 emissions from gas - Emissões acumuladas de CO2 do gás', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(125, 25, 'cumulative_luc_co2', 'Cumulative CO2 emissions from land-use change - Emissões acumuladas de CO2 da mudança no uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(126, 25, 'cumulative_oil_co2', 'Cumulative CO2 emissions from oil - Emissões acumuladas de CO2 do petróleo', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(127, 25, 'cumulative_other_co2', 'Cumulative CO2 emissions from other industry - Emissões acumuladas de CO2 de outras indústrias', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(128, 25, 'energy_per_capita', 'Primary energy consumption per capita - Consumo de energia primária por pessoa', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(129, 25, 'energy_per_gdp', 'Primary energy consumption per GDP - Consumo de energia primária por PIB', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(130, 25, 'flaring_co2', 'Annual CO2 emissions from flaring - Emissões anuais de CO2 da queima de gás', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(131, 25, 'flaring_co2_per_capita', 'Annual CO2 emissions from flaring (per capita) - Emissões anuais de CO2 da queima de gás (por pessoa)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(132, 25, 'gas_co2', 'Annual CO2 emissions from gas - Emissões anuais de CO2 do gás', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(133, 25, 'gas_co2_per_capita', 'Annual CO2 emissions from gas (per capita) - Emissões anuais de CO2 do gás (por pessoa)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(134, 25, 'ghg_excluding_lucf_per_capita', 'Per capita greenhouse gas emissions from fossil fuels and industry - Emissões per capita de gases de efeito estufa de combustíveis fósseis e indústria', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(135, 25, 'ghg_per_capita', 'Per capita greenhouse gas emissions including land use - Emissões per capita de gases de efeito estufa, incluindo uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(136, 25, 'land_use_change_co2', 'Annual CO2 emissions from land-use change - Emissões anuais de CO2 da mudança no uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(137, 25, 'land_use_change_co2_per_capita', 'Annual CO2 emissions from land-use change per capita - Emissões anuais de CO2 da mudança no uso da terra (por pessoa)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(138, 25, 'methane', 'Annual methane emissions including land use - Emissões anuais de metano, incluindo uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(139, 25, 'methane_per_capita', 'Per capita methane emissions including land use - Emissões per capita de metano, incluindo uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(140, 25, 'nitrous_oxide', 'Annual nitrous oxide emissions including land use - Emissões anuais de óxido nitroso, incluindo uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(141, 25, 'nitrous_oxide_per_capita', 'Per capita nitrous oxide emissions including land use - Emissões per capita de óxido nitroso, incluindo uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(142, 25, 'oil_co2', 'Annual CO2 emissions from oil - Emissões anuais de CO2 do petróleo', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(143, 25, 'oil_co2_per_capita', 'Annual CO2 emissions from oil (per capita) - Emissões anuais de CO2 do petróleo (por pessoa)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(144, 25, 'other_co2_per_capita', 'Annual CO2 emissions from other industry (per capita) - Emissões anuais de CO2 de outras indústrias (por pessoa)', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(145, 25, 'other_industry_co2', 'Annual CO2 emissions from other industry - Emissões anuais de CO2 de outras indústrias', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(146, 25, 'primary_energy_consumption', 'Primary energy consumption - Consumo de energia primária', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(147, 25, 'share_global_cement_co2', 'Share of global annual CO2 emissions from cement - Participação nas emissões globais anuais de CO2 do cimento', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(148, 25, 'share_global_co2', 'Share of global annual CO2 emissions - Participação nas emissões globais anuais de CO2', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(149, 25, 'share_global_co2_including_luc', 'Share of global annual CO2 emissions including land-use change - Participação nas emissões globais anuais de CO2, incluindo mudanças no uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(150, 25, 'share_global_coal_co2', 'Share of global annual CO2 emissions from coal - Participação nas emissões globais anuais de CO2 do carvão', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(151, 25, 'share_global_cumulative_cement_co2', 'Share of global cumulative CO2 emissions from cement - Participação nas emissões globais acumuladas de CO2 do cimento', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(152, 25, 'share_global_cumulative_co2', 'Share of global cumulative CO2 emissions - Participação nas emissões globais acumuladas de CO2', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(153, 25, 'share_global_cumulative_co2_including_luc', 'Share of global cumulative CO2 emissions including land-use change - Participação nas emissões globais acumuladas de CO2, incluindo mudanças no uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(154, 25, 'share_global_cumulative_coal_co2', 'Share of global cumulative CO2 emissions from coal - Participação nas emissões globais acumuladas de CO2 do carvão', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(155, 25, 'share_global_cumulative_flaring_co2', 'quantidade de CO2 emitido per capita', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(156, 25, 'share_global_cumulative_gas_co2', 'Share of global cumulative CO2 emissions from flaring - Participação nas emissões globais acumuladas de CO2 da queima de gás', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(157, 25, 'share_global_cumulative_luc_co2', 'Share of global cumulative CO2 emissions from land-use change - Participação nas emissões globais acumuladas de CO2 da mudança no uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(158, 25, 'share_global_cumulative_oil_co2', 'Share of global cumulative CO2 emissions from oil - Participação nas emissões globais acumuladas de CO2 do petróleo', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(159, 25, 'share_global_cumulative_other_co2', 'Share of global cumulative CO2 emissions from other industry - Participação nas emissões globais acumuladas de CO2 de outras indústrias', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(160, 25, 'share_global_flaring_co2', 'Share of global annual CO2 emissions from flaring - Participação nas emissões globais anuais de CO2 da queima de gás', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(161, 25, 'share_global_gas_co2', 'Share of global annual CO2 emissions from gas - Participação nas emissões globais anuais de CO2 do gás', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(162, 25, 'share_global_luc_co2', 'Share of global annual CO2 emissions from land-use change - Participação nas emissões globais anuais de CO2 da mudança no uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(163, 25, 'share_global_oil_co2', 'Share of global annual CO2 emissions from oil - Participação nas emissões globais anuais de CO2 do petróleo', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(164, 25, 'share_global_other_co2', 'Share of global annual CO2 emissions from other industry - Participação nas emissões globais anuais de CO2 de outras indústrias', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(165, 25, 'share_of_temperature_change_from_ghg', 'Share of contribution to global warming - Participação na contribuição para o aquecimento global', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(166, 25, 'temperature_change_from_ch4', 'Change in global mean surface temperature caused by methane emissions - Mudança na temperatura média global causada pelas emissões de metano', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(167, 25, 'temperature_change_from_co2', 'Change in global mean surface temperature caused by CO2 emissions - Mudança na temperatura média global causada pelas emissões de CO2', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(168, 25, 'temperature_change_from_ghg', 'Change in global mean surface temperature caused by greenhouse gas emissions - Mudança na temperatura média global causada pelas emissões de gases de efeito estufa', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(169, 25, 'temperature_change_from_n2o', 'Change in global mean surface temperature caused by nitrous oxide emissions - Mudança na temperatura média global causada pelas emissões de óxido nitroso', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(170, 25, 'total_ghg', 'Annual greenhouse gas emissions including land use - Emissões anuais de gases de efeito estufa, incluindo uso da terra', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(171, 25, 'total_ghg_excluding_lucf', 'Annual greenhouse gas emissions from fossil fuels and industry - Emissões anuais de gases de efeito estufa de combustíveis fósseis e indústria', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(172, 25, 'trade_co2', 'Annual CO2 emissions embedded in trade - Emissões anuais de CO2 incorporadas no comércio', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS VALUES 
(173, 25, 'trade_co2_share', 'Share of annual CO2 emissions embedded in trade - Participação nas emissões anuais de CO2 incorporadas no comércio', 'FLOAT', 'VALUE', 'ZZZ,ZZZ,ZZ9.999');


INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(56, 95, 'Há apenas o país chamado WORLD ou mundo para agregar tudo');
INSERT INTO workspace.pucrio.CATALOGO_COLUNA_DADOS_OBS VALUES 
(58, 95, 'Algumas entidades não possuem a sigla do país, isso significa que é uma entidade agrupada, exemplo: North American - América do Norte.');

# %% [markdown]
# #7. Catálogo de dados normalizados.
# Aqui serão descritas as tabelas e campos que serão usados para normalizar os dados coletados nos Insights.

# %% [markdown]
# ##7.1. Descrição tabelas
#
# **REGIOES** - Representa regiões geográficas (continentes e sub-regiões) com base no catálogo de países.
#
# **PAISES** - Dimensão de países, com dados demográficos e ligação à região.
#
# **SETORES** - Setores de emissão (Power, Industry, etc.) — baseado em CARBON_MONITOR, CW, etc.
#
# **FORMATO_VALORES** - Especifica unidades e fatores de conversão (ex: MtCO₂e → toneladas).
#
# **PRODUTOS** -Produtos agrícolas e itens relacionados (ex: rice, meat_cattle), com ligação ao formato.
#
# **ANOS** - Dimensão de tempo (ano), com validação de faixa.
#
# **EMISSAO_CO2_ANUAL** - Emissões agregadas globais por ano (ex: WORLD de Carbon Monitor ou somatório OWID).
#
# **EMISSAO_CO2_PER_CAPITA** - Valor médio global per capita por ano (ex: de OWID).
#
# **EMISSAO_CO2_PIB** - Emissão por unidade de PIB global (ex: co2_per_gdp médio mundial).
#
# **EMISSAO_CO2_SETOR** - Total por setor (global, ano agregado).
#
# **EMISSAO_CO2_PRODUTOS** - Total por produto agrícola (ex: soma de emission_intensity_* × produção estimada ou intensidade média).
#
# **EMISSAO_CO2_PAIS** - Emissões por país e ano (principal fato do modelo).
#
# **EMISSAO_CO2_REGIAO** - Emissões por setor e ano (ex: Power em 2023).
#
# **EMISSAO_CO2_ANUAL_PER_CAPITA** - Emissões por produto e ano (ex: rice em 1961, MtCO₂e).
#
# **EMISSAO_CO2_ANUAL_PIB** - Emissões por país, ano e relacionadas ao PIB, para armazenar apenas o indicador per-PIB como fato independente.
#
# **EMISSAO_CO2_ANUAL_SETOR** - Emissões por setor e ano (ex: Power em 2023).
#
# **EMISSAO_CO2_ANUAL_PRODUTO** - Emissões por produto e ano (ex: rice em 1961, MtCO₂e).
#
# **EMISSAO_CO2_ANUAL_PAIS** - Emissões por país e ano (principal fato do modelo).
#
# **EMISSAO_CO2_ANUAL_REGIAO** - Emissões por região e ano (ex: Europa, 2020), obtida por soma agrupada de países.
#
# **EMISSAO_CO2_PAIS_SETOR** - Emissões por país e setor (ano agregado ou média).
#
# **EMISSAO_CO2_PAIS_PRODUTOS** - Emissões por país e produto agrícola (ex: meat_cattle no Brasil).
#
# **EMISSAO_CO2_REGIAO_SETOR** - Emissões por região × setor (ex: Américas × Energy).
#
# **EMISSAO_CO2_REGIAO_PRODUTOS** - Emissões por região × produto agrícola (ex: África × meat_cattle).

# %% [markdown]
# ##7.2. SQL Criação tabelas

# %%
# %sql
CREATE TABLE IF NOT EXISTS workspace.pucrio.regiao (
  id_regiao      BIGINT GENERATED ALWAYS AS IDENTITY,
  sigla_regiao   STRING NOT NULL,
  nome_regiao    STRING NOT NULL,
  CONSTRAINT pk_regiao PRIMARY KEY (id_regiao)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.pais (
  id_pais         BIGINT GENERATED ALWAYS AS IDENTITY,
  sigla_pais      STRING NOT NULL,          -- ISO Alpha-3 (ex: BRA)
  nome_pais       STRING NOT NULL,          -- Nome comum (ex: Brazil)
  populacao_pais  BIGINT,
  pib_pais        DOUBLE,                   -- PIB nominal (USD)
  id_regiao       BIGINT NOT NULL,
  CONSTRAINT pk_pais PRIMARY KEY (id_pais),
  CONSTRAINT fk_pais_regiao FOREIGN KEY (id_regiao) REFERENCES workspace.pucrio.regiao(id_regiao)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.setor (
  id_setor        BIGINT GENERATED ALWAYS AS IDENTITY,
  sigla_setor     STRING NOT NULL,
  nome_setor      STRING NOT NULL,
  descricao_setor STRING,
  CONSTRAINT pk_setor PRIMARY KEY (id_setor)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.formato_valores (
  id_formato       BIGINT GENERATED ALWAYS AS IDENTITY,
  sigla_formato    STRING NOT NULL,      -- ex: MT, TON, KG
  nome_formato     STRING NOT NULL,      -- ex: 'Megatoneladas CO₂e'
  fator_conversao  DOUBLE NOT NULL,      -- para conversão → toneladas
  CONSTRAINT pk_formato PRIMARY KEY (id_formato)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.produto (
  id_produto            BIGINT GENERATED ALWAYS AS IDENTITY,
  sigla_produto         STRING NOT NULL,
  nome_produto          STRING NOT NULL,
  descricao_produto     STRING,
  id_formato_valores    BIGINT NOT NULL,
  CONSTRAINT pk_produto PRIMARY KEY (id_produto),
  CONSTRAINT fk_produto_formato FOREIGN KEY (id_formato_valores) REFERENCES workspace.pucrio.formato_valores(id_formato)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.ano (
  id_ano  BIGINT GENERATED ALWAYS AS IDENTITY,
  ano     INT NOT NULL,
  CONSTRAINT pk_ano PRIMARY KEY (id_ano)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_anual (
  id_ano            BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE NOT NULL,  -- em toneladas (padrão)
  CONSTRAINT pk_anual PRIMARY KEY (id_ano),
  CONSTRAINT fk_anual_ano FOREIGN KEY (id_ano) REFERENCES workspace.pucrio.ano(id_ano),
  CONSTRAINT fk_emissao_anual_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES  workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_per_capita (
  id_ano            BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,
  CONSTRAINT pk_per_capita PRIMARY KEY (id_ano),
  CONSTRAINT fk_per_capita_ano FOREIGN KEY (id_ano) REFERENCES workspace.pucrio.ano(id_ano),
  CONSTRAINT fk_emissao_per_capita_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_pib (
  id_ano            BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,
  CONSTRAINT pk_pib PRIMARY KEY (id_ano),
  CONSTRAINT fk_pib_ano FOREIGN KEY (id_ano) REFERENCES workspace.pucrio.ano(id_ano),
  CONSTRAINT fk_emissao_pib_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_setor (
  id_setor          BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,
  CONSTRAINT pk_emissao_setor PRIMARY KEY (id_setor),
  CONSTRAINT fk_emissao_setor FOREIGN KEY (id_setor) REFERENCES workspace.pucrio.setor(id_setor),
  CONSTRAINT fk_emissao_setor_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_produto (
  id_produto        BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,
  CONSTRAINT pk_emissao_produto PRIMARY KEY (id_produto),
  CONSTRAINT fk_emissao_produto FOREIGN KEY (id_produto) REFERENCES workspace.pucrio.produto(id_produto),
  CONSTRAINT fk_emissao_produto_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_anual_pais (
  id_ano            BIGINT NOT NULL,
  id_pais           BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,
  valor_per_capita  DOUBLE,
  valor_per_pib     DOUBLE,
  CONSTRAINT pk_emissao_anual_pais PRIMARY KEY (id_ano, id_pais),
  CONSTRAINT fk_emissao_anual_pais_ano FOREIGN KEY (id_ano) REFERENCES workspace.pucrio.ano(id_ano),
  CONSTRAINT fk_emissao_anual_pais_pais FOREIGN KEY (id_pais) REFERENCES workspace.pucrio.pais(id_pais),
  CONSTRAINT fk_emissao_anual_pais_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_anual_setor (
  id_ano            BIGINT NOT NULL,
  id_setor          BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,
  CONSTRAINT pk_emissao_anual_setor PRIMARY KEY (id_ano, id_setor),
  CONSTRAINT fk_emissao_anual_setor_ano FOREIGN KEY (id_ano) REFERENCES workspace.pucrio.ano(id_ano),
  CONSTRAINT fk_emissao_anual_setor_setor FOREIGN KEY (id_setor) REFERENCES workspace.pucrio.setor(id_setor),
  CONSTRAINT fk_emissao_anual_setor_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_anual_produto (
  id_ano            BIGINT NOT NULL,
  id_produto        BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,
  CONSTRAINT pk_emissao_anual_produto PRIMARY KEY (id_ano, id_produto),
  CONSTRAINT fk_emissao_anual_produto_ano FOREIGN KEY (id_ano) REFERENCES workspace.pucrio.ano(id_ano),
  CONSTRAINT fk_emissao_anual_produto_produto FOREIGN KEY (id_produto) REFERENCES workspace.pucrio.produto(id_produto),
  CONSTRAINT fk_emissao_anual_produto_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_pais_setor (
  id_pais           BIGINT NOT NULL,
  id_setor          BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,
  CONSTRAINT pk_emissao_pais_setor PRIMARY KEY (id_pais, id_setor),
  CONSTRAINT fk_emissao_pais_setor_pais FOREIGN KEY (id_pais) REFERENCES workspace.pucrio.pais(id_pais),
  CONSTRAINT fk_emissao_pais_setor_setor FOREIGN KEY (id_setor) REFERENCES workspace.pucrio.setor(id_setor),
  CONSTRAINT fk_emissao_pais_setor_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_pais_produto (
  id_pais           BIGINT NOT NULL,
  id_produto        BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,
  CONSTRAINT pk_emissao_pais_produto PRIMARY KEY (id_pais, id_produto),
  CONSTRAINT fk_emissao_pais_produto_pais FOREIGN KEY (id_pais) REFERENCES workspace.pucrio.pais(id_pais),
  CONSTRAINT fk_emissao_pais_produto_produto FOREIGN KEY (id_produto) REFERENCES workspace.pucrio.produto(id_produto),
  CONSTRAINT fk_emissao_pais_produto_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_regiao_setor (
  id_regiao     BIGINT NOT NULL,
  id_setor      BIGINT NOT NULL,
  id_fonte_dados INT NOT NULL,
  valor_emissao DOUBLE,  -- em toneladas (CO₂ ou CO₂e, conforme fonte)
  CONSTRAINT pk_emissao_regiao_setor PRIMARY KEY (id_regiao, id_setor),
  CONSTRAINT fk_emissao_regiao_setor_regiao FOREIGN KEY (id_regiao) REFERENCES workspace.pucrio.regiao(id_regiao),
  CONSTRAINT fk_emissao_regiao_setor_setor FOREIGN KEY (id_setor) REFERENCES workspace.pucrio.setor(id_setor),
  CONSTRAINT fk_emissao_regiao_setor_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_regiao_produto (
  id_regiao     BIGINT NOT NULL,
  id_produto    BIGINT NOT NULL,
  id_fonte_dados INT NOT NULL,
  valor_emissao DOUBLE,  -- em toneladas (CO₂e)
  CONSTRAINT pk_emissao_regiao_produto PRIMARY KEY (id_regiao, id_produto),
  CONSTRAINT fk_emissao_regiao_produto_regiao FOREIGN KEY (id_regiao) REFERENCES workspace.pucrio.regiao(id_regiao),
  CONSTRAINT fk_emissao_regiao_produto_produto FOREIGN KEY (id_produto) REFERENCES workspace.pucrio.produto(id_produto),
  CONSTRAINT fk_emissao_regiao_produto_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_anual_pais (
  id_ano            BIGINT NOT NULL,
  id_pais           BIGINT NOT NULL,
  id_fonte_dados    INT NOT NULL,
  valor_emissao     DOUBLE,  -- CO₂ total (excl. LULUCF), em toneladas
  valor_per_capita  DOUBLE,  -- toneladas / pessoa
  valor_per_pib     DOUBLE,  -- toneladas / mil USD (PIB nominal)
  CONSTRAINT pk_emissao_anual_pais PRIMARY KEY (id_ano, id_pais),
  CONSTRAINT fk_emissao_anual_pais_ano FOREIGN KEY (id_ano) REFERENCES workspace.pucrio.ano(id_ano),
  CONSTRAINT fk_emissao_anual_pais_pais FOREIGN KEY (id_pais) REFERENCES workspace.pucrio.pais(id_pais),
  CONSTRAINT fk_emissao_anual_pais_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_anual_regiao (
  id_ano        BIGINT NOT NULL,
  id_regiao     BIGINT NOT NULL,
  id_fonte_dados INT NOT NULL,
  valor_emissao DOUBLE,  -- em toneladas
  CONSTRAINT pk_emissao_anual_regiao PRIMARY KEY (id_ano, id_regiao),
  CONSTRAINT fk_emissao_anual_regiao_ano FOREIGN KEY (id_ano) REFERENCES workspace.pucrio.ano(id_ano),
  CONSTRAINT fk_emissao_anual_regiao_regiao FOREIGN KEY (id_regiao) REFERENCES workspace.pucrio.regiao(id_regiao),
  CONSTRAINT fk_emissao_anual_regiao_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

CREATE TABLE IF NOT EXISTS workspace.pucrio.emissao_co2_anual_pib (
  id_ano        BIGINT NOT NULL,
  id_pais       BIGINT NOT NULL,
  id_fonte_dados INT NOT NULL,
  valor_emissao DOUBLE,  -- valor_per_pib já em toneladas / mil USD
  CONSTRAINT pk_emissao_fato_anual_pib PRIMARY KEY (id_ano, id_pais),
  CONSTRAINT fk_emissao_anual_pib_ano FOREIGN KEY (id_ano) REFERENCES workspace.pucrio.ano(id_ano),
  CONSTRAINT fk_emissao_anual_pib_pais FOREIGN KEY (id_pais) REFERENCES workspace.pucrio.pais(id_pais),
  CONSTRAINT fk_emissao_anual_pib_fonte_dados FOREIGN KEY (id_fonte_dados) REFERENCES workspace.pucrio.catalogo_fontes_dados(ID_FONTE)
)
USING DELTA;

# %% [markdown]
# ##7.3. Inserção dos dados de tabelas mestres
# Nesta seção será inserido os códigos de dados das tabelas mestres, sendo elas:
#
# - REGIAO
# - PAIS
# - SETOR
# - FORMATO_VALORES
# - PRODUTO
# - ANOS

# %%
# %sql

--TABELA REGIAO
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('ANT', 'ANTÁRTIDA'); 
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('ART', 'ARTICO');
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('SEA', 'OCEANO/MAR');
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('AMS', 'AMÉRICA DO SUL');
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('AMC', 'AMÉRICA CENTRAL');
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('AMN', 'AMÉRICA DO NORTE');
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('EUR', 'EUROPA');
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('AFR', 'ÁFRICA');
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('ASI', 'ÁSIA');
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('OCE', 'OCEANIA');
INSERT INTO WORKSPACE.PUCRIO.REGIAO (SIGLA_REGIAO, NOME_REGIAO) VALUES ('WOR', 'WORLD / MUNDO');

--TABELA ANOS
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2025);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2024);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2023);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2022);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2021);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2020);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2019);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2018);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2017);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2016);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2015);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2014);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2013);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2012);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2011);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2010);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2009);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2008);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2007);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2006);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2005);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2004);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2003);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2002);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2001);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (2000);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1999);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1998);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1997);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1996);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1995);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1994);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1993);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1992);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1991);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1990);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1989);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1988);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1987);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1986);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1985);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1984);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1983);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1982);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1981);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1980);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1979);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1978);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1977);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1976);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1975);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1974);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1973);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1972);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1971);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1970);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1969);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1968);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1967);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1966);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1965);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1964);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1963);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1962);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1961);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1960);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1959);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1958);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1957);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1956);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1955);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1954);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1953);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1952);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1951);
INSERT INTO workspace.pucrio.ANO (ANO) VALUES (1950);

--FORMATO_VALORES
INSERT INTO workspace.pucrio.formato_valores (sigla_formato, nome_formato, fator_conversao)
VALUES
  ('MT', 'Megatoneladas CO₂e', 1e6),
  ('TON', 'Toneladas CO₂', 1.0),
  ('KG', 'Quilogramas CO₂', 1e-3),
  ('G', 'Gramas CO₂', 1e-6); 


--SETORES
INSERT INTO workspace.pucrio.setor (sigla_setor, nome_setor, descricao_setor)
VALUES
  ('ENERGY', 'Energy', 'Emissões do setor energético: geração de eletricidade, calor, combustão estacionária.'),
  ('IND_PROCESS', 'Industrial Processes and Product Use', 'Processos industriais não energéticos (ex: cimento, química, metalurgia).'),
  ('AGRICULTURE', 'Agriculture', 'Emissões de atividades agrícolas (solo, arroz, gado, fertilizantes).'),
  ('LULUCF', 'Land Use, Land-Use Change and Forestry', 'Mudança no uso da terra e florestas (sumidouros ou fontes).'),
  ('WASTE', 'Waste', 'Tratamento de resíduos sólidos e efluentes.'),
  ('OTHER', 'Other', 'Emissões residuais não atribuíveis diretamente aos demais setores.'),
  ('POWER', 'Power', 'Geração de energia elétrica (sub-setor de Energy, comum no Carbon Monitor).'),
  ('INDUSTRY', 'Industry', 'Combustão industrial + processos (sub-agregado de IND_PROCESS + parte de ENERGY).'),
  ('TRANSPORT', 'Transport', 'Rodoviário, aéreo, marítimo e ferroviário.'),
  ('RESIDENTIAL', 'Residential', 'Consumo energético em residências (aquecimento, cozinha, etc.).'),
  ('COMMERCIAL', 'Commercial and Institutional', 'Edifícios comerciais, públicos e serviços.'),
  ('FLARING', 'Flaring', 'Queima de gás associado à extração de petróleo/gás.'),
  ('CARRIER', 'Fugitive Emissions', 'Emissões fugitivas de produção e distribuição de combustíveis fósseis.'),
  ('AVIATION_INT', 'International Aviation', 'Emissões de voos internacionais (ICAO).'),
  ('SHIPPING_INT', 'International Shipping', 'Emissões marítimas internacionais (IMO).'),
  ('GROUND_TRANS', 'Ground Transport', 'Transporte terrestre'),
  ('DOMESTIC_AVI', 'Domestic Aviation', 'Aviação doméstica ou dentro do país e viagens de aviões curtas');


--PRODUTOS
INSERT INTO workspace.pucrio.produto 
(sigla_produto, nome_produto, descricao_produto, id_formato_valores)
VALUES
-- === Intensidades de emissão (kg CO₂eq/kg produto) → KG (id_formato = 1) ===
('CEREALS', 'Cereais (excl. arroz)', 'kg CO₂eq por kg de cereais (excluindo arroz)', 1),
('EGGS', 'Ovos', 'kg CO₂eq por kg de ovos', 1),
('MEAT_CATTLE', 'Carne de gado bovino', 'kg CO₂eq por kg de carne bovina', 1),
('MEAT_BUFFALO', 'Carne de búfalo', 'kg CO₂eq por kg de carne de búfalo', 1),
('MEAT_PIG', 'Carne de porco', 'kg CO₂eq por kg de carne suína', 1),
('MEAT_CHICKEN', 'Carne de frango', 'kg CO₂eq por kg de carne de frango', 1),
('MEAT_GOAT', 'Carne de cabra', 'kg CO₂eq por kg de carne de cabra', 1),
('MEAT_SHEEP', 'Carne de ovelha', 'kg CO₂eq por kg de carne de ovelha', 1),
('RICE', 'Arroz (paddy)', 'kg CO₂eq por kg de arroz em casca', 1),
('MILK_COW', 'Leite de vaca', 'kg CO₂eq por kg de leite de vaca', 1),
('MILK_BUFFALO', 'Leite de búfalo', 'kg CO₂eq por kg de leite de búfalo', 1),
('MILK_GOAT', 'Leite de cabra', 'kg CO₂eq por kg de leite de cabra', 1),
('MILK_SHEEP', 'Leite de ovelha', 'kg CO₂eq por kg de leite de ovelha', 1),
('MILK_CAMEL', 'Leite de camelo', 'kg CO₂eq por kg de leite de camelo', 1),

-- === Emissões totais por item agrícola (toneladas) → TON (id_formato = 2) ===
('AGR_1', 'Produção agrícola total', 'Emissões totais do setor agrícola (toneladas CO₂e)', 2),
('AGR_2', 'Cultivo de arroz', 'Emissões do cultivo de arroz irrigado (toneladas CO₂e)', 2),
('AGR_3', 'Enteric fermentation', 'Fermentação entérica em ruminantes (toneladas CO₂e)', 2),
('AGR_4', 'Manejo de dejetos', 'Manejo de dejetos animais (toneladas CO₂e)', 2),
('AGR_5', 'Queima de resíduos agrícolas', 'Queima de resíduos no campo (toneladas CO₂e)', 2),
('AGR_6', 'Cultivo de solo', 'Emissões diretas do solo (N₂O) por fertilizantes (toneladas CO₂e)', 2),
('AGR_7', 'Queima de biomassa', 'Queima de biomassa para limpeza de área (toneladas CO₂e)', 2),
('AGR_9', 'Produção de arroz irrigado (CH₄)', 'Metano do arroz irrigado (toneladas CO₂e)', 2),
('AGR_18', 'Outros processos agrícolas', 'Outras fontes menores do setor agrícola (toneladas CO₂e)', 2),

-- === Produtos de produção/comércio (toneladas) → TON (id_formato = 2) ===
('PROD_MAIZE', 'Milho', 'Produção de milho (toneladas)', 2),
('PROD_RICE', 'Arroz', 'Produção de arroz (toneladas)', 2),
('PROD_WHEAT', 'Trigo', 'Produção de trigo (toneladas)', 2),
('PROD_SOY', 'Soja', 'Produção de soja (toneladas)', 2),
('PROD_CATTLE', 'Gado', 'Produção de gado (cabeças/toneladas equivalente)', 2),
('PROD_PIG', 'Porco', 'Produção de suínos (toneladas)', 2),
('PROD_CHICKEN', 'Frango', 'Produção de frango (toneladas)', 2),
('PROD_GOAT', 'Cabra', 'Produção de caprinos (toneladas)', 2),

-- === Comércio (toneladas) → TON (id_formato = 2) ===
('IMP_RICE', 'Importação de arroz', 'Importação de arroz (toneladas)', 2),
('IMP_WHEAT', 'Importação de trigo', 'Importação de trigo (toneladas)', 2),
('IMP_MAIZE', 'Importação de milho', 'Importação de milho (toneladas)', 2),
('IMP_SOY', 'Importação de soja', 'Importação de soja (toneladas)', 2),
('EXP_RICE', 'Exportação de arroz', 'Exportação de arroz (toneladas)', 2),
('EXP_WHEAT', 'Exportação de trigo', 'Exportação de trigo (toneladas)', 2),
('EXP_MAIZE', 'Exportação de milho', 'Exportação de milho (toneladas)', 2),
('EXP_SOY', 'Exportação de soja', 'Exportação de soja (toneladas)', 2);
 
-- PAÍS
INSERT INTO workspace.pucrio.pais
(sigla_pais, nome_pais, populacao_pais, pib_pais, id_regiao)
VALUES
-- AMÉRICA DO SUL (id_regiao = 4)
('ARG', 'Argentina', 46044703, 649486000000, 4),
('BOL', 'Bolivia', 12079047, 46601000000, 4),
('BRA', 'Brazil', 214326223, 2130000000000, 4),
('CHL', 'Chile', 19493184, 344000000000, 4),
('COL', 'Colombia', 51609474, 341000000000, 4),
('ECU', 'Ecuador', 17643060, 120000000000, 4),
('GUF', 'French Guiana', 298710, NULL, 4),
('GUY', 'Guyana', 793804, 17800000000, 4),
('PRY', 'Paraguay', 6703860, 42000000000, 4),
('PER', 'Peru', 33402157, 266000000000, 4),
('SUR', 'Suriname', 617210, 10000000000, 4),
('URY', 'Uruguay', 3423107, 73000000000, 4),
('VEN', 'Venezuela', 28301696, NULL, 4),

-- AMÉRICA CENTRAL (id_regiao = 5)
('BLZ', 'Belize', 405272, 2600000000, 5),
('CRI', 'Costa Rica', 5121067, 70000000000, 5),
('SLV', 'El Salvador', 6520689, 33000000000, 5),
('GTM', 'Guatemala', 17109746, 98000000000, 5),
('HND', 'Honduras', 10069684, 33000000000, 5),
('MEX', 'Mexico', 128455129, 1812000000000, 5),  -- MIGRADO PARA AMC (critério ONU: América Central inclui México)
('NIC', 'Nicaragua', 6850666, 17000000000, 5),
('PAN', 'Panama', 4351267, 83000000000, 5),

-- CARIBE (id_regiao = 5)
('ATG', 'Antigua and Barbuda', 94220, 1800000000, 5),
('BHS', 'Bahamas', 402544, 13000000000, 5),
('BRB', 'Barbados', 281200, 5500000000, 5),
('CUB', 'Cuba', 11256314, NULL, 5),
('DMA', 'Dominica', 72413, 600000000, 5),
('DOM', 'Dominican Republic', 11117873, 114000000000, 5),
('GRD', 'Grenada', 124583, 1400000000, 5),
('HTI', 'Haiti', 11525899, 21000000000, 5),
('JAM', 'Jamaica', 2688393, 18000000000, 5),
('KNA', 'Saint Kitts and Nevis', 47760, 1100000000, 5),
('LCA', 'Saint Lucia', 180772, 2400000000, 5),
('VCT', 'Saint Vincent and the Grenadines', 103000, 900000000, 5),
('TTO', 'Trinidad and Tobago', 1525663, 29000000000, 5),

-- AMÉRICA DO NORTE (id_regiao = 6)
('CAN', 'Canada', 38246108, 2178000000000, 6),
('USA', 'United States', 331893745, 26949000000000, 6),

-- EUROPA (id_regiao = 7)
('ALB', 'Albania', 2854191, 22000000000, 7),
('AND', 'Andorra', 79824, 3500000000, 7),
('AUT', 'Austria', 8917205, 482000000000, 7),
('BLR', 'Belarus', 9379952, 76000000000, 7),
('BEL', 'Belgium', 11632186, 620000000000, 7),
('BIH', 'Bosnia and Herzegovina', 3263459, 27000000000, 7),
('BGR', 'Bulgaria', 6927288, 87000000000, 7),
('HRV', 'Croatia', 4036355, 79000000000, 7),
('CYP', 'Cyprus', 1244186, 30000000000, 7),
('CZE', 'Czechia', 10698896, 367000000000, 7),
('DNK', 'Denmark', 5857729, 406000000000, 7),
('EST', 'Estonia', 1331822, 39000000000, 7),
('FIN', 'Finland', 5540720, 301000000000, 7),
('FRA', 'France', 67749632, 3031000000000, 7),
('DEU', 'Germany', 83190556, 4427000000000, 7),
('GRC', 'Greece', 10348244, 244000000000, 7),
('HUN', 'Hungary', 9709886, 202000000000, 7),
('ISL', 'Iceland', 372295, 29000000000, 7),
('IRL', 'Ireland', 5033160, 594000000000, 7),
('ITA', 'Italy', 59109684, 2172000000000, 7),
('LVA', 'Latvia', 1862700, 41000000000, 7),
('LIE', 'Liechtenstein', 38387, 7000000000, 7),
('LTU', 'Lithuania', 2794700, 70000000000, 7),
('LUX', 'Luxembourg', 645397, 87000000000, 7),
('MLT', 'Malta', 514564, 21000000000, 7),
('MDA', 'Moldova', 2571777, 16000000000, 7),
('MCO', 'Monaco', 36297, 8000000000, 7),
('MNE', 'Montenegro', 622137, 6000000000, 7),
('NLD', 'Netherlands', 17533405, 1012000000000, 7),
('MKD', 'North Macedonia', 2083459, 15000000000, 7),
('NOR', 'Norway', 5391369, 514000000000, 7),
('POL', 'Poland', 37899108, 713000000000, 7),
('PRT', 'Portugal', 10281762, 273000000000, 7),
('ROU', 'Romania', 19186201, 358000000000, 7),
('RUS', 'Russian Federation', 143449286, 2060000000000, 7),
('SMR', 'San Marino', 33628, 2000000000, 7),
('SRB', 'Serbia', 6963764, 68000000000, 7),
('SVK', 'Slovakia', 5456362, 122000000000, 7),
('SVN', 'Slovenia', 2108977, 64000000000, 7),
('ESP', 'Spain', 47363824, 1565000000000, 7),
('SWE', 'Sweden', 10379295, 591000000000, 7),
('CHE', 'Switzerland', 8636896, 872000000000, 7),
('UKR', 'Ukraine', 41167336, 210000000000, 7),
('GBR', 'United Kingdom', 67325224, 3329000000000, 7),
('VAT', 'Vatican City', 882, 0, 7),

-- ÁFRICA (id_regiao = 8)
('DZA', 'Algeria', 44903225, 236000000000, 8),
('AGO', 'Angola', 33933610, 93000000000, 8),
('BEN', 'Benin', 12990482, 19000000000, 8),
('BWA', 'Botswana', 2397240, 20000000000, 8),
('BFA', 'Burkina Faso', 22120048, 20000000000, 8),
('BDI', 'Burundi', 12550186, 3000000000, 8),
('CPV', 'Cabo Verde', 567867, 2900000000, 8),
('CMR', 'Cameroon', 27922259, 48000000000, 8),
('CAF', 'Central African Republic', 4923715, 2600000000, 8),
('TCD', 'Chad', 17179740, 13000000000, 8),
('COM', 'Comoros', 850910, 1400000000, 8),
('COD', 'Congo (DRC)', 102263000, 62000000000, 8),
('COG', 'Congo (Republic)', 5657000, 12000000000, 8),
('CIV', 'Côte d’Ivoire', 27050278, 76000000000, 8),
('DJI', 'Djibouti', 1104545, 6500000000, 8),
('EGY', 'Egypt', 110990103, 477000000000, 8),
('GNQ', 'Equatorial Guinea', 1454147, 11000000000, 8),
('ERI', 'Eritrea', 3620312, 3000000000, 8),
('ETH', 'Ethiopia', 123267025, 157000000000, 8),
('GAB', 'Gabon', 2287789, 21000000000, 8),
('GMB', 'Gambia', 2482028, 2200000000, 8),
('GHA', 'Ghana', 32103042, 79000000000, 8),
('GIN', 'Guinea', 13832212, 21000000000, 8),
('GNB', 'Guinea-Bissau', 1994655, 2100000000, 8),
('KEN', 'Kenya', 54027487, 118000000000, 8),
('LSO', 'Lesotho', 2159069, 3000000000, 8),
('LBR', 'Liberia', 5206176, 4000000000, 8),
('LBY', 'Libya', 6958536, 48000000000, 8),
('MDG', 'Madagascar', 29158070, 16000000000, 8),
('MWI', 'Malawi', 20203663, 14000000000, 8),
('MLI', 'Mali', 21899546, 24000000000, 8),
('MRT', 'Mauritania', 4775110, 11000000000, 8),
('MUS', 'Mauritius', 1265138, 15000000000, 8),
('MAR', 'Morocco', 37271872, 144000000000, 8),
('MOZ', 'Mozambique', 32163045, 17000000000, 8),
('NAM', 'Namibia', 2540302, 15000000000, 8),
('NER', 'Niger', 25250480, 16000000000, 8),
('NGA', 'Nigeria', 211400708, 472000000000, 8),
('RWA', 'Rwanda', 13651383, 12000000000, 8),
('STP', 'Sao Tome and Principe', 223362, 600000000, 8),
('SEN', 'Senegal', 17196308, 31000000000, 8),
('SYC', 'Seychelles', 99258, 2000000000, 8),
('SLE', 'Sierra Leone', 8423212, 5000000000, 8),
('SOM', 'Somalia', 17057655, 8000000000, 8),
('ZAF', 'South Africa', 60041999, 408000000000, 8),
('SSD', 'South Sudan', 10572147, 3000000000, 8),
('SDN', 'Sudan', 44909353, 34000000000, 8),
('SWZ', 'Eswatini', 1172368, 4000000000, 8),
('TZA', 'Tanzania', 62814864, 80000000000, 8),
('TGO', 'Togo', 8482324, 8000000000, 8),
('TUN', 'Tunisia', 11923615, 45000000000, 8),
('UGA', 'Uganda', 47123924, 46000000000, 8),
('ZMB', 'Zambia', 19609648, 29000000000, 8),
('ZWE', 'Zimbabwe', 15092171, 28000000000, 8),

-- ÁSIA (id_regiao = 9)
('AFG', 'Afghanistan', 39835428, 9000000000, 9),
('ARM', 'Armenia', 2963907, 26000000000, 9),
('AZE', 'Azerbaijan', 10139175, 82000000000, 9),
('BHR', 'Bahrain', 1781427, 42000000000, 9),
('BGD', 'Bangladesh', 169356251, 456000000000, 9),
('BTN', 'Bhutan', 777486, 3700000000, 9),
('BRN', 'Brunei', 440951, 12000000000, 9),
('KHM', 'Cambodia', 16926984, 33000000000, 9),
('CHN', 'China', 1412360000, 17963000000000, 9),
('CYP', 'Cyprus', 1244186, 30000000000, 9),  -- repete (mas comum em ambas regiões)
('PRK', 'North Korea', 25778815, NULL, 9),
('KOR', 'South Korea', 51305186, 1802000000000, 9),
('GEO', 'Georgia', 3720400, 27000000000, 9),
('HKG', 'Hong Kong SAR', 7514700, 386000000000, 9),
('IND', 'India', 1393409038, 3736900000000, 9),
('IDN', 'Indonesia', 273753191, 1319000000000, 9),
('IRN', 'Iran', 83153341, 437000000000, 9),
('IRQ', 'Iraq', 40222493, 259000000000, 9),
('ISR', 'Israel', 9216900, 481000000000, 9),
('JPN', 'Japan', 125700000, 4231000000000, 9),
('JOR', 'Jordan', 10203134, 53000000000, 9),
('KAZ', 'Kazakhstan', 19002101, 235000000000, 9),
('KWT', 'Kuwait', 4270563, 182000000000, 9),
('KGZ', 'Kyrgyzstan', 6610316, 10000000000, 9),
('LAO', 'Laos', 7275556, 21000000000, 9),
('LBN', 'Lebanon', 5217953, 24000000000, 9),
('MAC', 'Macao SAR', 649341, 29000000000, 9),
('MYS', 'Malaysia', 32744966, 432000000000, 9),
('MDV', 'Maldives', 540542, 7700000000, 9),
('MNG', 'Mongolia', 3278290, 22000000000, 9),
('MMR', 'Myanmar', 54409800, 76000000000, 9),
('NPL', 'Nepal', 29136808, 41000000000, 9),
('OMN', 'Oman', 4520471, 92000000000, 9),
('PAK', 'Pakistan', 235824862, 382000000000, 9),
('PSE', 'Palestine', 5202889, 18000000000, 9),
('PHL', 'Philippines', 113880328, 418000000000, 9),
('QAT', 'Qatar', 2658150, 228000000000, 9),
('SAU', 'Saudi Arabia', 35340671, 1062000000000, 9),
('SGP', 'Singapore', 5453600, 493000000000, 9),
('LKA', 'Sri Lanka', 22156000, 86000000000, 9),
('SYR', 'Syria', 22152403, NULL, 9),
('TWN', 'Taiwan', 23402571, 789000000000, 9),
('TJK', 'Tajikistan', 9750064, 11000000000, 9),
('THA', 'Thailand', 69799978, 545000000000, 9),
('TLS', 'Timor-Leste', 1318442, 3700000000, 9),
('TUR', 'Türkiye', 83210743, 1022000000000, 9),
('TKM', 'Turkmenistan', 6031187, 58000000000, 9),
('ARE', 'United Arab Emirates', 9890400, 507000000000, 9),
('UZB', 'Uzbekistan', 34232050, 80000000000, 9),
('VNM', 'Vietnam', 97580000, 432000000000, 9),
('YEM', 'Yemen', 30491363, 31000000000, 9),

-- OCEÂNIA (id_regiao = 10)
('ASM', 'American Samoa', 49710, 660000000, 10),
('AUS', 'Australia', 25694905, 1692000000000, 10),
('COK', 'Cook Islands', 17459, 360000000, 10),
('FJI', 'Fiji', 902199, 6100000000, 10),
('PYF', 'French Polynesia', 280904, 2800000000, 10),
('GUM', 'Guam', 168485, 6100000000, 10),
('KIR', 'Kiribati', 119446, 2400000000, 10),
('MHL', 'Marshall Islands', 42415, 260000000, 10),
('FSM', 'Micronesia', 115021, 400000000, 10),
('NRU', 'Nauru', 10834, 130000000, 10),
('NCL', 'New Caledonia', 271407, 10000000000, 10),
('NZL', 'New Zealand', 5091100, 256000000000, 10),
('NIU', 'Niue', 1620, 22000000, 10),
('NFK', 'Norfolk Island', 1748, 10000000, 10),
('MNP', 'Northern Mariana Islands', 55194, 1000000000, 10),
('PLW', 'Palau', 18008, 300000000, 10),
('PNG', 'Papua New Guinea', 9119000, 34000000000, 10),
('WSM', 'Samoa', 200475, 1000000000, 10),
('SLB', 'Solomon Islands', 686884, 1800000000, 10),
('TKL', 'Tokelau', 1411, 3000000, 10),
('TON', 'Tonga', 100651, 550000000, 10),
('TUV', 'Tuvalu', 11204, 60000000, 10),
('VUT', 'Vanuatu', 307145, 1000000000, 10),
('WLF', 'Wallis and Futuna', 11620, 60000000, 10),

-- ANTÁRTIDA (id_regiao = 1)
('ATA', 'Antarctica', 1300, NULL, 1),

-- TERRITÓRIOS ÁRTICOS / MARÍTIMOS (id_regiao = 2 ou 3 — aqui atribuído a ANT/SEA por simplicidade)
('ATA', 'Heard Island and McDonald Islands', 0, NULL, 1),
('ATA', 'South Georgia and the South Sandwich Islands', 0, NULL, 1),
('FRO', 'Faroe Islands', 48863, 2800000000, 7),  -- Dinamarca → Europa
('WOR', 'World', 8004000000, 116000000000000, 12);

# %% [markdown]
# #8. Scripts SQL´s para Insights
# Foram criados alguns SQL´s para os insigths de dados,
#
# **- Estão apenas os SQL´s relacionaddos à dados que contenham informações de emissão de dióxido de carbono (CO2)**
# **- Caso os dados e informações coletadas sejam de anos anteriores à 1950, os mesmos serão filtrados/ignorados.**
#
# Cada consulta irá realizar uma inserção dos dados em tabelas criadas e normalizadas para a armazenagem correta dos dados

# %% [markdown]
# ##Detalhamento dos campos e valores
# Abaixo estará um valor com os detalhamentos de valores, campos, e formatos de gravações nas tabelas, para fins de padronização.
#
#
# ###Para os valores de MtCO2/day (MtCO2/dia):
# MtCO2/day significa megatoneladas de dióxido de carbono por dia. É uma unidade de medida utilizada para quantificar a taxa de emissões de dióxido de carbono (CO₂) em larga escala, geralmente em contextos de monitoramento global, nacional ou industrial das mudanças climáticas.
# A notação se divide da seguinte forma:
# * Mt significa megatoneladas, ou seja, um milhão de toneladas métricas (1.000.000 de toneladas).
# * CO₂ refere-se ao dióxido de carbono, o principal gás de efeito estufa emitido por atividades humanas, como a queima de combustíveis fósseis e a produção de cimento.
# * /day indica a medição por dia (taxa diária).
#
#
# ###Para os valores gravados nas tabelas
# * A padronização dos valores gravados nas tabelas serão de toneladas, então todos os valores dos dados coletados serão convertidos para toneladas.
# * Um estudo sugere que (1) tonelada de (CO2) pode ser compensada por (7,14) árvores da Mata Atlântica
# * Cada tonelada de (CO2) equivale a (1) crédito de carbono, que pode ser negociado no mercado.
# * São necessários cerca de 435 litros de gasolina para produzir 1 tonelada (1.000kg) de CO2.

# %% [markdown]
# ##8.1. CARBON MONITOR

# %% [markdown]
# ###8.1.1 HISTORICAL EMISSIONS

# %% [markdown]
# Histórico de emissões de dióxido de carbono diário (**MtCO2/day**) por países e setores, entretanto na consulta abaixo o consumo foi agregado em uma soma para contabilizar anualmente os valores e com isso serão realizados as inserções nas seguintes tabelas:
# - emissao_co2_anual
# - emissao_co2_anual_pais
# - emissao_co2_anual_setor
# - emissao_co2_pais_setor
# - emissao_co2_setor
#
# **Os valores serão convertidos em toneladas**

# %%
# %sql
--CONSULTA GERAL DO CARBON MONITOR COM TODOS OS DADOS E TODAS AS COLUNAS
SELECT CASE WHEN COUNTRY = 'EU27 & UK' THEN 'EUR' ELSE COUNTRY END PAIS, 
       CAST(substr(DATE, 7, 10) AS NUMERIC) ANO,
       SECTOR SETOR,
       SUM(VALUE) VALOR --CO2 emitidos por ano MtCO2/day
FROM workspace.pucrio.CARBON_MONITOR
GROUP BY 
       COUNTRY, 
       CAST(substr(DATE, 7, 10) AS NUMERIC),
       SECTOR
       ;

# %%
# %sql
--COM BASE NA CONSULTA ANTERIOR, ESTA SERÁ A INSERÇÃO NO EMISSAO_CO2_ANUAL
INSERT INTO WORKSPACE.PUCRIO.EMISSAO_CO2_ANUAL (ID_ANO, id_fonte_dados, valor_emissao)
SELECT ANO.ID_ANO,  
       1,
       SUM(carbon_monitor.value) * formato_valores.fator_conversao VALOR_CONVERTIDO --CO2 emitidos por ano de CO2 em Toneladas
  FROM workspace.pucrio.CARBON_MONITOR
 INNER JOIN workspace.pucrio.ANO 
    ON ANO.ANO = CAST(substr(carbon_monitor.DATE, 7, 10) AS NUMERIC) 
 INNER JOIN workspace.pucrio.formato_valores ON ID_FORMATO = 1
 GROUP BY 
       ANO.ID_ANO,
       formato_valores.fator_conversao
       ;

# %%
# %sql
--COM BASE NA CONSULTA ANTERIOR, ESTA SERÁ A INSERÇÃO NA TABELA DE EMISSAO_CO2_ANUAL_PAIS 
INSERT INTO workspace.pucrio.emissao_co2_anual_pais (id_pais, id_ano, id_fonte_dados, valor_emissao) 
SELECT PAIS.ID_PAIS, 
       ANO.id_ano,       
       1, 
       SUM(carbon_monitor.VALUE) * formato_valores.fator_conversao VALOR_CONVERTIDO 
  FROM workspace.pucrio.CARBON_MONITOR
 INNER JOIN workspace.pucrio.ANO 
    ON ANO.ANO = CAST(substr(carbon_monitor.DATE, 7, 10) AS NUMERIC) 
 INNER JOIN workspace.pucrio.formato_valores 
    ON formato_valores.ID_FORMATO = 1
 INNER JOIN workspace.pucrio.pais
    ON UPPER(CASE WHEN carbon_monitor.COUNTRY = 'EU27 & UK' THEN 'Europe' ELSE CARBON_MONITOR.COUNTRY END) = UPPER(PAIS.nome_pais)
GROUP BY 
       PAIS.ID_PAIS, 
       ANO.id_ano,
       formato_valores.fator_conversao
       ;

# %%
# %sql
--COM BASE NA CONSULTA ANTERIOR, ESTA SERÁ A INSERÇÃO NA TABELA DE emissao_co2_anual_setor 
INSERT INTO workspace.pucrio.emissao_co2_anual_setor (id_setor, id_ano, id_fonte_dados, valor_emissao) 
SELECT SETOR.ID_SETOR,
       ANO.id_ano,    
       1,   
       SUM(carbon_monitor.VALUE) * formato_valores.fator_conversao VALOR_CONVERTIDO 
  FROM workspace.pucrio.CARBON_MONITOR
 INNER JOIN workspace.pucrio.ANO 
    ON ANO.ANO = CAST(substr(carbon_monitor.DATE, 7, 10) AS NUMERIC) 
 INNER JOIN workspace.pucrio.formato_valores 
    ON formato_valores.ID_FORMATO = 1
 INNER JOIN workspace.pucrio.SETOR
    ON UPPER(carbon_monitor.sector) = UPPER(SETOR.nome_setor)
GROUP BY 
       SETOR.ID_SETOR, 
       ANO.id_ano,
       formato_valores.fator_conversao
       ;

# %%
# %sql
--COM BASE NA CONSULTA ANTERIOR, ESTA SERÁ A INSERÇÃO NA TABELA DE emissao_co2_pais_setor 
INSERT INTO workspace.pucrio.emissao_co2_pais_setor (id_pais, id_setor, id_fonte_dados, valor_emissao) 
SELECT PAIS.ID_PAIS,  
       SETOR.ID_SETOR,
       1,
       SUM(carbon_monitor.VALUE) * formato_valores.fator_conversao VALOR_CONVERTIDO 
  FROM workspace.pucrio.CARBON_MONITOR
 INNER JOIN workspace.pucrio.SETOR
    ON UPPER(carbon_monitor.sector) = UPPER(SETOR.nome_setor)
 INNER JOIN workspace.pucrio.formato_valores 
    ON formato_valores.ID_FORMATO = 1
 INNER JOIN workspace.pucrio.pais
    ON UPPER(CASE WHEN carbon_monitor.COUNTRY = 'EU27 & UK' THEN 'Europe' ELSE CARBON_MONITOR.COUNTRY END) = UPPER(PAIS.nome_pais)
 GROUP BY 
      PAIS.ID_PAIS, 
      SETOR.ID_SETOR,
      formato_valores.fator_conversao
;

# %%
# %sql
--COM BASE NA CONSULTA ANTERIOR, ESTA SERÁ A INSERÇÃO NA TABELA DE emissao_co2_setor 
INSERT INTO workspace.pucrio.emissao_co2_setor (id_setor, id_fonte_dados, valor_emissao) 
SELECT SETOR.ID_SETOR,    
       1,   
       SUM(carbon_monitor.VALUE) * formato_valores.fator_conversao VALOR_CONVERTIDO 
  FROM workspace.pucrio.CARBON_MONITOR 
 INNER JOIN workspace.pucrio.formato_valores 
    ON formato_valores.ID_FORMATO = 1
 INNER JOIN workspace.pucrio.SETOR
    ON UPPER(SETOR.nome_setor) = UPPER(carbon_monitor.sector)
GROUP BY  
      SETOR.id_setor,
      formato_valores.fator_conversao
      ;

# %% [markdown]
# ##8.2. CLIMATE WATCH

# %% [markdown]
# ###8.3.1 AGRICULTURE EMISSION

# %%
# %sql
WITH EMISSIONS AS (
       SELECT 
              AREA PAIS, 
              YEAR ANO, 
              `short names` PRODUTO,
              EMISSIONS VALOR --CO2  kg CO2eq/kg de produto 
       FROM cw_agriculture_emissions
       UNPIVOT (
       EMISSIONS FOR YEAR IN (
              `1961`, `1962`, `1963`, `1964`, `1965`, `1966`, `1967`, `1968`, `1969`, `1970`,
              `1971`, `1972`, `1973`, `1974`, `1975`, `1976`, `1977`, `1978`, `1979`, `1980`,
              `1981`, `1982`, `1983`, `1984`, `1985`, `1986`, `1987`, `1988`, `1989`, `1990`,
              `1991`, `1992`, `1993`, `1994`, `1995`, `1996`, `1997`, `1998`, `1999`, `2000`,
              `2001`, `2002`, `2003`, `2004`, `2005`, `2006`, `2007`, `2008`, `2009`, `2010`,
              `2011`, `2012`, `2013`, `2014`, `2015`, `2016`, `2017`, `2018`, `2019`, `2020`,
              `2021`
       )
       ) AS unpivoted_data
)
SELECT B.*
  FROM EMISSIONS B;

# %% [markdown]
# ###8.3.2. - HISTORICAL EMISSIONS

# %%
# %sql
WITH EMISSIONS AS (
       SELECT 
              ISO PAIS, 
              YEAR ANO, 
              SECTOR SETOR,
              EMISSIONS VALOR --CO2  MtCO₂e
       FROM cw_historical_emissions
       UNPIVOT (
       EMISSIONS FOR YEAR IN (
              `1961`, `1962`, `1963`, `1964`, `1965`, `1966`, `1967`, `1968`, `1969`, `1970`,
              `1971`, `1972`, `1973`, `1974`, `1975`, `1976`, `1977`, `1978`, `1979`, `1980`,
              `1981`, `1982`, `1983`, `1984`, `1985`, `1986`, `1987`, `1988`, `1989`, `1990`,
              `1991`, `1992`, `1993`, `1994`, `1995`, `1996`, `1997`, `1998`, `1999`, `2000`,
              `2001`, `2002`, `2003`, `2004`, `2005`, `2006`, `2007`, `2008`, `2009`, `2010`,
              `2011`, `2012`, `2013`, `2014`, `2015`, `2016`, `2017`, `2018`, `2019`, `2020`,
              `2021`, `2022`, `2023`
       )
       ) AS unpivoted_data
)
SELECT B.*
  FROM EMISSIONS B;

# %% [markdown]
# ##8.3. FAOSTAT

# %% [markdown]
# ###7.3.1. HISTORICAL EMISSIONS TOTALS

# %%
# %sql
WITH EMISSIONS AS (
       SELECT 
              AREA PAIS, 
              substr(YEAR, 2, 4) ANO, 
              ITEM PRODUTO,
              ELEMENT GAS,
              EMISSIONS VALOR --CO2  KT (kt)
       FROM faostat_emissions_totals
       UNPIVOT (
       EMISSIONS FOR YEAR IN (
              `Y1961`, `Y1962`, `Y1963`, `Y1964`, `Y1965`, `Y1966`, `Y1967`, `Y1968`, `Y1969`, `Y1970`,
              `Y1971`, `Y1972`, `Y1973`, `Y1974`, `Y1975`, `Y1976`, `Y1977`, `Y1978`, `Y1979`, `Y1980`,
              `Y1981`, `Y1982`, `Y1983`, `Y1984`, `Y1985`, `Y1986`, `Y1987`, `Y1988`, `Y1989`, `Y1990`,
              `Y1991`, `Y1992`, `Y1993`, `Y1994`, `Y1995`, `Y1996`, `Y1997`, `Y1998`, `Y1999`, `Y2000`,
              `Y2001`, `Y2002`, `Y2003`, `Y2004`, `Y2005`, `Y2006`, `Y2007`, `Y2008`, `Y2009`, `Y2010`,
              `Y2011`, `Y2012`, `Y2013`, `Y2014`, `Y2015`, `Y2016`, `Y2017`, `Y2018`, `Y2019`, `Y2020`,
              `Y2021`, `Y2022`, `Y2023`, `Y2030`, `Y2050` 
       )
       ) AS unpivoted_data
       WHERE `Element Code` IN ('724313','723113','724413','7273','717815')
)
SELECT B.*
  FROM EMISSIONS B;

# %% [markdown]
# ##8.4. IEA

# %% [markdown]
# ###8.4.1. EMISSIONS PER COUNTRIES

# %%
# %sql
WITH EMISSIONS AS (
       SELECT 
              Country PAIS, 
              YEAR ANO,  
              `Type emission` GAS,
              EMISSIONS VALOR, --CO2  Mt CO2
              `Grow rate % 2019-20` COMPARATIVO_2019_20_PERC,
              `Grow rate % 2020-21` COMPARATIVO_2020_21_PERC
       FROM iea_emissions
       UNPIVOT (
       EMISSIONS FOR YEAR IN (
              `2019`, `2020`, `2021`
       )
       ) AS unpivoted_data
)
SELECT B.*
  FROM EMISSIONS B;

# %% [markdown]
# ###8.4.2. EMISSIONS PER  GASES EMISSIONS

# %%
# %sql
WITH EMISSIONS AS (
       SELECT 
              YEAR ANO,  
              `Type emission` GAS,
              `CO2 emissions` PRODUTO,
              EMISSIONS VALOR, --CO2  Mt CO2
              `Grow rate % 2019-20` COMPARATIVO_2019_20_PERC,
              `Grow rate % 2020-21` COMPARATIVO_2020_21_PERC
       FROM iea_gas_emissions
       UNPIVOT (
       EMISSIONS FOR YEAR IN (
              `2019`, `2020`, `2021`
       )
       ) AS unpivoted_data
)
SELECT B.*
  FROM EMISSIONS B;

# %% [markdown]
# ##8.5. NASA

# %% [markdown]
# ###8.5.1. - CO2 FLUX TOTAL
#
# Os dados quase serão ignorados, pois não mostram a quantidade de emissão de CO2 por países, renda per capita, PIB e/ou outro indicador, apenas por área e latitude e logitude e a área, e isso acabou inviabilizando o projeto, pois mesmo com um script em python bem refinado ainda poderá haver situações em que as informações ficarão erradas para certos países, e isso acabará que mostrando valores inconsistentes.
#
# Entretanto, o valor destas informações obtidas na NASA são muito interessantes, e com isso poderá ser usado um consumo anual/mensal/diário para o planeta todo
#
# Também foi identificado valores de emissão de Dióxido de Carbono (CO2) negativos, estes valores negativos são provinientes de latitudes e longitudes em locais como: Antartida (extremo polo sul), Groelândia (extremo polo norte), e alguns locais de alto mar, até mesmo próximos à linha do Equador. Isso mostra a importância destes dados, pois com estas informações e mais algumas pesquisas científicas (não tão aprofundadas), passamos a entender a importância do derretimento das calotas polares, aquecimento dos mares e o aumento do nível do mar.
#
# **Conclusão**
# Quanto à este dado da Nasa, quanto menor o valor (mais negativo for) para estes locais, melhor é para a saúde geral do planeta (no caso para o aquecimento global), pois estará absorvendo mais raios ultravioletas e mantendo a temperatura geral do planeta estável.
#
# **Observação**
# A consulta e a inclusão das informações abaixo estão em um nível agregado de valor anual, ou seja, para conseguir chegar no valor de emissão de CO2 negativo, precisa retirar a agregação.

# %%
# %sql
SELECT ANO,
       SUM(VALOR) VALOR
FROM (
       SELECT CAST(substr(CAST(TRUNC(TIME, 'YEAR') AS STRING), 1, 4) AS NUMERIC) ANO,
              total_post VALOR, --g/m^2/day
              area qtd_area_m2
       FROM workspace.pucrio.nasa_cms_flux_total
)
GROUP BY ANO
ORDER BY 1;

# %% [markdown]
# ##8.6. ONU

# %% [markdown]
# ###8.6.1. HISTORICAL EMISSIONS

# %%
# %sql
WITH EMISSIONS AS (
       SELECT 
              PARTY PAIS,
              YEAR ANO,  
              EMISSIONS VALOR, --KT
              `Base Year` VALOR_ANO_BASE, --kt
              `Change from base year to latest reported year` COMPARATIVO_ANO_BASE_ULTIMO_ANO, --%
              `Last Inventory Year 2021` ANO_ULTIMO_INVENTARIO --%      
       FROM onu_time_series_co_2_total
       UNPIVOT (
       EMISSIONS FOR YEAR IN (
              `1990`, `1991`, `1992`, `1993`, `1994`, `1995`, `1996`, `1997`, `1998`, `1999`, `2000`, `2001`, `2002`, `2003`, `2004`, `2005`, `2006`, `2007`, `2008`, `2009`, `2010`, `2011`, `2012`, `2013`, `2014`, `2015`, `2016`, `2017`, `2018`, `2019`, `2020`
       )
       ) AS unpivoted_data
)
SELECT B.*
  FROM EMISSIONS B;

# %% [markdown]
# ###8.6.2. CO2 REMOVIDOS

# %%
# %sql
WITH EMISSIONS AS (
       SELECT 
              PARTY PAIS,
              YEAR ANO,  
              EMISSIONS VALOR, --KT
              `Base Year` VALOR_ANO_BASE, --kt
              `Last Inventory Year (2021)` ANO_ULTIMO_INVENTARIO --%      
       FROM onu_annual_emissions_removals
       UNPIVOT (
       EMISSIONS FOR YEAR IN (
              `1990`, `1991`, `1992`, `1993`, `1994`, `1995`, `1996`, `1997`, `1998`, `1999`, `2000`, `2001`, `2002`, `2003`, `2004`, `2005`, `2006`, `2007`, `2008`, `2009`, `2010`, `2011`, `2012`, `2013`, `2014`, `2015`, `2016`, `2017`, `2018`, `2019`, `2020`
       )
       ) AS unpivoted_data
)
SELECT B.*
  FROM EMISSIONS B;

# %% [markdown]
# ###8.6.3. GREENHOUSE GAS

# %%
# %sql
WITH EMISSIONS AS (
       SELECT 
              Category SECTOR,
              YEAR ANO,  
              EMISSIONS VALOR, --KT
              `Base year` VALOR_ANO_BASE,
              `Last Inventory Year 2021` ANO_ULTIMO_INVENTARIO
       FROM onu_annual_greenhouse_gas
       UNPIVOT (
       EMISSIONS FOR YEAR IN (
              `1990`, `1991`, `1992`, `1993`, `1994`, `1995`, `1996`, `1997`, `1998`, `1999`, `2000`, `2001`, `2002`, `2003`, `2004`, `2005`, `2006`, `2007`, `2008`, `2009`, `2010`, `2011`, `2012`, `2013`, `2014`, `2015`, `2016`, `2017`, `2018`, `2019`, `2020`
       )
       ) AS unpivoted_data
)
SELECT B.*
  FROM EMISSIONS B;

# %% [markdown]
# ##8.7. OUR WORLD DATA

# %% [markdown]
# ###8.7.1. CO2 EMISSIONS ANUAL PER COUNTRY

# %%
# %sql
SELECT CODE PAIS, --SE ESTIVER NULO É UMA REGIÃO OU CONTINENTE E ENTÃO USAR O NOME DO PAÍS
       ENTITY NOME_PAIS, 
       YEAR ANO,       
       SUM(`Annual CO₂ emissions`) VALOR
  FROM workspace.pucrio.owd_annual_co_2_emissions_per_country
 GROUP BY CODE,
       YEAR,
       Entity;

# %% [markdown]
# ###8.7.2. CO2 EMISSIONS SHARE ANNUAL CO2

# %%
# %sql
SELECT CODE PAIS, --SE ESTIVER NULO É UMA REGIÃO OU CONTINENTE E ENTÃO USAR O NOME DO PAÍS
       ENTITY NOME_PAIS, 
       YEAR ANO,       
       SUM(`Share of global annual CO₂ emissions`) VALOR
  FROM workspace.pucrio.owd_annual_share_of_co_2_emissions
 GROUP BY CODE,
       YEAR,
       Entity;

# %% [markdown]
# ###8.7.3. CO2 EMISSIONS FACTOR

# %%
# %sql
SELECT ENTITY NOME_FATOR, 
       YEAR ANO,       
       SUM(`CO₂ emission factor`) VALOR
  FROM  workspace.pucrio.owd_carbon_dioxide_emissions_factor
 GROUP BY 
       YEAR,
       Entity;

# %% [markdown]
# ###8.7.4. CO2 CONCENTRATION LONG TERM (ONLY WORLD)

# %%
# %sql
SELECT YEAR ANO, --HÁ ANOS NEGATIVOS E ANOS COM VALORES MUITO BAIXOS
       SUM(`Annual concentration of atmospheric carbon dioxide`) VALOR
  FROM workspace.pucrio.owd_co_2_long_term_concentration
 WHERE YEAR > 1950
 GROUP BY YEAR;

# %% [markdown]
# ###8.7.5. CO2 EMISSIONS PER CAPITA

# %%
# %sql
SELECT Entity NOME_PAIS, 
       Code PAIS, --SE ESTIVER NULO É UMA REGIÃO OU CONTINENTE E ENTÃO USAR O NOME DO PAÍS
       YEAR ANO,
       SUM(`Annual CO₂ emissions (per capita)`) VALOR
  FROM  workspace.pucrio.owd_co_emissions_per_capita 
 GROUP BY Entity, 
       Code, 
       YEAR;

# %% [markdown]
# ###8.7.6. CO2 EMISSIONS CUMALITIVE

# %%
# %sql
SELECT Entity NOME_PAIS, 
       Code PAIS, --SE ESTIVER NULO É UMA REGIÃO OU CONTINENTE E ENTÃO USAR O NOME DO PAÍS
       YEAR ANO,
       SUM(`Cumulative CO₂ emissions`) VALOR
  FROM  workspace.pucrio.owd_cumulative_co_emissions
 GROUP BY Entity, 
       Code, 
       YEAR;

# %% [markdown]
# ###8.7.7. CO2 CUMALITIVE SHARE

# %%
# %sql
SELECT Entity NOME_PAIS, 
       Code PAIS, --SE ESTIVER NULO É UMA REGIÃO OU CONTINENTE E ENTÃO USAR O NOME DO PAÍS
       YEAR ANO,
       SUM(`Share of global cumulative CO₂ emissions`) VALOR
  FROM   workspace.pucrio.owd_share_of_cumulative_co_2
 GROUP BY Entity, 
       Code, 
       YEAR;

# %% [markdown]
# ###8.7.8. CO2 EMISSIONS FOR ALL

# %%
# %sql
SELECT 
  country AS PAIS,
  ISO_CODE AS SIGLA_PAIS,
  year AS ANO,
  population AS POPULACAO,
  gdp AS PIB,

  --  CIMENTO
  SUM(cement_co2) AS VALOR_EMITIDO_CO2_CIMENTO,
  cement_co2_per_capita AS VALOR_PER_CAPITA_CO2_CIMENTO,

  --  CARVÃO
  SUM(coal_co2) AS VALOR_EMITIDO_CO2_CARBONIFERO,
  coal_co2_per_capita AS VALOR_PER_CAPITA_CO2_CARBONIFERO,

  --  GÁS NATURAL
  SUM(gas_co2) AS VALOR_EMITIDO_CO2_GAS_NATURAL,
  gas_co2_per_capita AS VALOR_PER_CAPITA_CO2_GAS_NATURAL,

  --  PETRÓLEO
  SUM(oil_co2) AS VALOR_EMITIDO_CO2_PETROLEO,
  oil_co2_per_capita AS VALOR_PER_CAPITA_CO2_PETROLEO,

  --  QUEIMA DE GAS FLARE
  SUM(flaring_co2) AS VALOR_EMITIDO_CO2_REVEJAMENTO,
  flaring_co2_per_capita AS VALOR_PER_CAPITA_CO2_REVEJAMENTO,

  --  MUDANÇA DE USO DA TERRA
  SUM(land_use_change_co2) AS VALOR_EMITIDO_CO2_MUDANCA_USO_SOLO,
  land_use_change_co2_per_capita AS VALOR_PER_CAPITA_CO2_MUDANCA_USO_SOLO,

  --  OUTRAS INDÚSTRIAS
  SUM(other_industry_co2) AS VALOR_EMITIDO_CO2_OUTRAS_INDUSTRIAS,

  -- CONSUMO E COMÉRCIO
  SUM(consumption_co2) AS VALOR_EMITIDO_CO2_CONSUMO,
  consumption_co2_per_capita AS VALOR_PER_CAPITA_CO2_CONSUMO,
  consumption_co2_per_gdp AS VALOR_PER_PIB_CO2_CONSUMO,
  SUM(trade_co2) AS VALOR_EMITIDO_CO2_COMERCIO,
  trade_co2_share AS PARTICIPACAO_CO2_COMERCIO_NO_GLOBAL,

  --  CO₂ TOTAL
  SUM(co2) AS VALOR_EMITIDO_CO2,
  co2_per_capita AS VALOR_PER_CAPITA_CO2,
  co2_per_gdp AS VALOR_PER_PIB_CO2,
  co2_per_unit_energy AS VALOR_PER_UNIDADE_ENERGIA_CO2,
  co2_growth_abs AS CRESCIMENTO_ABSOLUTO_CO2,
  co2_growth_prct AS CRESCIMENTO_PERCENTUAL_CO2,

  --  CO₂ INCLUINDO MUDANÇA DE USO DA TERRA
  SUM(co2_including_luc) AS VALOR_EMITIDO_CO2_INCL_MUDANCA_USO_SOLO,
  co2_including_luc_per_capita AS VALOR_PER_CAPITA_CO2_INCL_MUDANCA_USO_SOLO,
  co2_including_luc_per_gdp AS VALOR_PER_PIB_CO2_INCL_MUDANCA_USO_SOLO,
  co2_including_luc_per_unit_energy AS VALOR_PER_UNIDADE_ENERGIA_CO2_INCL_MUDANCA_USO_SOLO,
  co2_including_luc_growth_abs AS CRESCIMENTO_ABSOLUTO_CO2_INCL_MUDANCA_USO_SOLO,
  co2_including_luc_growth_prct AS CRESCIMENTO_PERCENTUAL_CO2_INCL_MUDANCA_USO_SOLO,

  --  METANO (CH4)
  SUM(methane) AS VALOR_EMITIDO_METANO,
  methane_per_capita AS VALOR_PER_CAPITA_METANO,

  --  ÓXIDO NITROSO (N2O)
  SUM(nitrous_oxide) AS VALOR_EMITIDO_OXIDO_NITROSO,
  nitrous_oxide_per_capita AS VALOR_PER_CAPITA_OXIDO_NITROSO,

  --  GASES DO EFEITO ESTUFA (GHG)
  SUM(total_ghg) AS VALOR_EMITIDO_TODOS_GASES_ESTUFA,
  SUM(total_ghg_excluding_lucf) AS VALOR_EMITIDO_GEE_EXC_LUCF,
  ghg_per_capita AS VALOR_PER_CAPITA_GEE,
  ghg_excluding_lucf_per_capita AS VALOR_PER_CAPITA_GEE_EXC_LUCF,

  --  ENERGIA
  primary_energy_consumption AS CONSUMO_PRIMARIO_ENERGIA,
  energy_per_capita AS ENERGIA_PER_CAPITA,
  energy_per_gdp AS ENERGIA_PER_PIB,

  --  PARTICIPAÇÃO GLOBAL (%)
  share_global_cement_co2 AS PARTICIPACAO_GLOBAL_CO2_CIMENTO,
  share_global_co2 AS PARTICIPACAO_GLOBAL_CO2,
  share_global_co2_including_luc AS PARTICIPACAO_GLOBAL_CO2_INCL_MUDANCA_USO_SOLO,
  share_global_coal_co2 AS PARTICIPACAO_GLOBAL_CO2_CARBONIFERO,
  share_global_gas_co2 AS PARTICIPACAO_GLOBAL_CO2_GAS_NATURAL,
  share_global_oil_co2 AS PARTICIPACAO_GLOBAL_CO2_PETROLEO,
  share_global_flaring_co2 AS PARTICIPACAO_GLOBAL_CO2_REVEJAMENTO,
  share_global_other_co2 AS PARTICIPACAO_GLOBAL_OUTROS_CO2,

  --  PARTICIPAÇÃO ACUMULADA GLOBAL
  cumulative_cement_co2 AS TOTAL_ACUMULADO_CO2_CIMENTO,
  cumulative_coal_co2 AS TOTAL_ACUMULADO_CO2_CARBONIFERO,
  cumulative_gas_co2 AS TOTAL_ACUMULADO_CO2_GAS_NATURAL,
  cumulative_oil_co2 AS TOTAL_ACUMULADO_CO2_PETROLEO,
  cumulative_flaring_co2 AS TOTAL_ACUMULADO_CO2_REVEJAMENTO,
  cumulative_luc_co2 AS TOTAL_ACUMULADO_CO2_MUDANCA_USO_SOLO,
  cumulative_other_co2 AS TOTAL_ACUMULADO_OUTROS_CO2,
  cumulative_co2 AS TOTAL_ACUMULADO_CO2,
  cumulative_co2_including_luc AS TOTAL_ACUMULADO_CO2_INCL_MUDANCA_USO_SOLO,

  --  PARTICIPAÇÃO EM EMISSÕES ACUMULADAS
  share_global_cumulative_cement_co2 AS PARTICIPACAO_ACUMULADA_CO2_CIMENTO,
  share_global_cumulative_coal_co2 AS PARTICIPACAO_ACUMULADA_CO2_CARBONIFERO,
  share_global_cumulative_gas_co2 AS PARTICIPACAO_ACUMULADA_CO2_GAS_NATURAL,
  share_global_cumulative_oil_co2 AS PARTICIPACAO_ACUMULADA_CO2_PETROLEO,
  share_global_cumulative_flaring_co2 AS PARTICIPACAO_ACUMULADA_CO2_REVEJAMENTO,
  share_global_cumulative_luc_co2 AS PARTICIPACAO_ACUMULADA_CO2_MUDANCA_USO_SOLO,
  share_global_cumulative_other_co2 AS PARTICIPACAO_ACUMULADA_OUTROS_CO2,
  share_global_cumulative_co2 AS PARTICIPACAO_ACUMULADA_CO2,
  share_global_cumulative_co2_including_luc AS PARTICIPACAO_ACUMULADA_CO2_INCL_MUDANCA_USO_SOLO,

  -- MUDANÇA DE TEMPERATURA (°C)
  temperature_change_from_co2 AS MUDANCA_TEMPERATURA_DEVIDO_CO2,
  temperature_change_from_ch4 AS MUDANCA_TEMPERATURA_DEVIDO_METANO,
  temperature_change_from_n2o AS MUDANCA_TEMPERATURA_DEVIDO_OXIDO_NITROSO,
  temperature_change_from_ghg AS MUDANCA_TEMPERATURA_DEVIDO_GEE,
  share_of_temperature_change_from_ghg AS PARTICIPACAO_MUDANCA_TEMP_GEE

FROM  workspace.pucrio.owid_co_2_data-- Substitua pelo nome real da sua tabela
WHERE YEAR > 1950
GROUP BY 
  country, ISO_CODE, year, population, gdp,
  cement_co2_per_capita,
  coal_co2_per_capita,
  gas_co2_per_capita,
  oil_co2_per_capita,
  flaring_co2_per_capita,
  land_use_change_co2_per_capita,
  consumption_co2_per_capita,
  consumption_co2_per_gdp,
  co2_per_capita,
  co2_per_gdp,
  co2_per_unit_energy,
  co2_growth_abs,
  co2_growth_prct,
  co2_including_luc_per_capita,
  co2_including_luc_per_gdp,
  co2_including_luc_per_unit_energy,
  co2_including_luc_growth_abs,
  co2_including_luc_growth_prct,
  methane_per_capita,
  nitrous_oxide_per_capita,
  ghg_per_capita,
  ghg_excluding_lucf_per_capita,
  primary_energy_consumption,
  energy_per_capita,
  energy_per_gdp,
  trade_co2_share,
  share_global_cement_co2,
  share_global_co2,
  share_global_co2_including_luc,
  share_global_coal_co2,
  share_global_gas_co2,
  share_global_oil_co2,
  share_global_flaring_co2,
  share_global_other_co2,
  share_global_cumulative_cement_co2,
  share_global_cumulative_co2,
  share_global_cumulative_co2_including_luc,
  share_global_cumulative_coal_co2,
  share_global_cumulative_gas_co2,
  share_global_cumulative_oil_co2,
  share_global_cumulative_flaring_co2,
  share_global_cumulative_luc_co2,
  share_global_cumulative_other_co2,
  share_of_temperature_change_from_ghg,
  temperature_change_from_co2,
  temperature_change_from_ch4,
  temperature_change_from_n2o,
  temperature_change_from_ghg,
  cumulative_cement_co2,
   cumulative_coal_co2,
  cumulative_gas_co2 ,
  cumulative_oil_co2,
  cumulative_flaring_co2 ,
  cumulative_luc_co2,
  cumulative_other_co2,
  cumulative_co2 ,
  cumulative_co2_including_luc;

# %% [markdown]
# #9 Inserção dos dados
# Nesta seção terá os scripts tratados para inserir os dados em todas as tabelas de dados normalizados, onde serão populadas as tabelas para que seja feitas as análises posteriores
